# %% [markdown]
# # Sentiment analysis

# %%
import pandas as pd
import numpy as np
from icecream import ic
import datetime
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import pyplot_themes as themes
import seaborn as sns; sns.set()
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pyplot_themes as themes
import datetime as dt

# %%
def set_base_plot_settings(fontsize, if_palette):
    matplotlib.rc('ytick', labelsize=fontsize)
    matplotlib.rc('xtick', labelsize=fontsize)
    themes.theme_minimal(grid=False, ticks=False, fontsize=fontsize)
    a4_dims = (25,15)
    
    if if_palette:
        #          0 black      1 orange  2 L blue   3 green    4 L orange  5 D blue  6 D orange 7 purple
        palette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]
    else:
        palette = 0
    
    fig, (ax1) = plt.subplots(1,1, figsize=a4_dims)
    sns.set(font_scale = 2)

    return fig, ax1, palette

def set_late_plot_settings(if_dates):
    ax1.set(xlabel="", ylabel = "")
    ax1.xaxis.get_label().set_fontsize(40)
    ax1.yaxis.get_label().set_fontsize(40)

    ax1.grid(color='darkgrey', linestyle='-', linewidth=0.5, which= "both")
    if if_dates:
        # Define the date format
        ax1.xaxis_date()
        date_form = mdates.DateFormatter("%d-%b")
        ax1.xaxis.set_major_formatter(date_form)

    ax1.set(ylim=(0, None))
    
    #ax1.set_yticklabels(ax1.get_yticks(), size = 35)

    #fig.suptitle("Mentions of 'vaccin*'. 2020 - 2021", size = "40")
    return fig, ax1

def set_late_barplot_settings():
    ax1.set(xlabel="", ylabel = "")
    ax1.xaxis.get_label().set_fontsize(40)
    ax1.yaxis.get_label().set_fontsize(40)
        
    #ax1.set_yticklabels(ax1.get_yticks(), size = 35)

    #fig.suptitle("Mentions of 'vaccin*'. 2020 - 2021", size = "40")
    return fig, ax1

# %%
#df = pd.read_csv("vaccin_vis_afinn.csv")
df = pd.read_csv("../hope-keyword-templates/vaccin_smoothed.csv")

df = df.sort_values("created_at")
df.head()
# Out:
#    index           created_at            id  \
# 0  33766  2021-01-01 00:05:19  1.344797e+18
# 1  33767  2021-01-01 00:06:23  1.344797e+18
# 2  33768  2021-01-01 00:18:57  1.344800e+18
# 3  33769  2021-01-01 00:19:03  1.344800e+18
# 4  33770  2021-01-01 00:23:55  1.344801e+18
#
#                                                 text search_keyword  \
# 0  Meget rørt her i Villa villakulla mormor’s Val...     ['vaccin']
# 1  Julen har ikke forladt os helt endnu og nytåre...     ['vaccin']
# 2  @LMSTSenderovitz US ser på samme princip. Gene...     ['vaccin']
# 3  Glædelig nytår til alle mine venner. Jeg håber...     ['vaccin']
# 4  @ufortalte @johannesnordby Det er jo det en va...     ['vaccin']
#
#          date                                  mentioneless_text  \
# 0  2021-01-01  Meget rørt her i Villa villakulla mormor’s Val...
# 1  2021-01-01  Julen har ikke forladt os helt endnu og nytåre...
# 2  2021-01-01   US ser på samme princip. Generelt er der ikke...
# 3  2021-01-01  Glædelig nytår til alle mine venner. Jeg håber...
# 4  2021-01-01    Det er jo det en vaccine skal gøre for at vi...
#
#                                               text50  dupe50    neg  ...  \
# 0  Meget rørt her i Villa villakulla mormor’s Val...   False  0.000  ...
# 1  Julen har ikke forladt os helt endnu og nytåre...   False  0.038  ...
# 2   US ser på samme princip. Generelt er der ikke...   False  0.034  ...
# 3  Glædelig nytår til alle mine venner. Jeg håber...   False  0.000  ...
# 4    Det er jo det en vaccine skal gøre for at vi...   False  0.036  ...
#
#           day   entropy  normalized_entropy  centered_entropy  s2000_entropy  \
# 0  2021-01-01  5.077014            0.494716          0.032951       5.083264
# 1  2021-01-01  5.077014            0.494716          0.032951       5.083271
# 2  2021-01-01  5.077014            0.494716          0.032951       5.083277
# 3  2021-01-01  5.077014            0.494716          0.032951       5.083284
# 4  2021-01-01  5.077014            0.494716          0.032951       5.083291
#
#   s2000_compound  s2000_nr_of_tweets  s5000_entropy  s5000_compound  \
# 0       0.044157          643.142835       5.120173        0.052946
# 1       0.044158          643.157608       5.120183        0.052948
# 2       0.044159          643.172422       5.120193        0.052951
# 3       0.044160          643.187277       5.120203        0.052954
# 4       0.044161          643.202172       5.120213        0.052957
#
#    s5000_nr_of_tweets
# 0          757.901141
# 1          757.935391
# 2          757.969645
# 3          758.003905
# 4          758.038168
#
# [5 rows x 25 columns]

# %%
df["date"] = pd.to_datetime(df["created_at"], utc=True).dt.strftime('%Y-%m-%d')
df["date"] = pd.to_datetime(df["date"])

#mask = (df['date'] >= '2020-12-15')
#df = df.loc[mask]

# %%
# Rolling average
#df['compound_7day_ave'] = df.compound.rolling(7).mean().shift(-3)
#df['compound_30day_ave'] = df.compound.rolling(30).mean().shift(-3)

# %%
#average_compound = sum(df["compound"]) / len(df["compound"])
#df["centered_compound"] = df["compound"] - average_compound

#average_sentida = sum(df["sentida_sentiment"]) / len(df["sentida_sentiment"])
#df["centered_sentida"] = df["sentida_sentiment"] - average_sentida

#min_afinn = min(df["afinn_sentiment"])
#max_afinn = max(df["afinn_sentiment"])
#difference = max_afinn - min_afinn

#df["normalized_afinn"] = (df["afinn_sentiment"] - min_afinn) / difference
#average_afinn = sum(df["normalized_afinn"]) / len(df["normalized_afinn"])
#df["centered_afinn"] = df["normalized_afinn"] - average_afinn

# %%
#df = pd.read_csv("winter_df_sent_entropy.csv")
#df["date"] = pd.to_datetime(df["date"])

# %%
matplotlib.rc('ytick', labelsize=20)
matplotlib.rc('xtick', labelsize=20)


themes.theme_minimal(grid=False, ticks=False, fontsize=18)
a4_dims = (25,15) #(11.7, 8.27)
#          0 black      1 orange  2 L blue   3 green    4 L orange  5 D blue  6 D orange 7 purple
palette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]


fig, (ax1) = plt.subplots(1,1, figsize=a4_dims)
sns.set(font_scale = 2)
ax1 = sns.lineplot(x="date", y="centered_compound", 
                   label="Vader", 
                   color = palette[2],
                     linewidth = 3, data = df)

# 'solid', 'dashed', 'dashdot', 'dotted'
#ax2 = ax1.twinx()
ax1 = sns.lineplot(x="date", y="centered_sentida", 
                   label="Sentida", 
                   color = palette[6],
                   #alpha = 0.50,
                     linewidth = 3, 
                   #linestyle = "dotted",
                   data = df)


ax1.set(xlabel="", ylabel = "")
ax1.xaxis.get_label().set_fontsize(40)
ax1.yaxis.get_label().set_fontsize(40)

ax1.grid(color='grey', linestyle='-', linewidth=0.5, which= "both")

# Define the date format
ax1.xaxis_date()
date_form = mdates.DateFormatter("%d-%m")
ax1.xaxis.set_major_formatter(date_form)

    
#fig.suptitle("Sentiment analysis of mentions of 'vaccin*'. 2020 - 2021", size = "40")

#plot_name = "fig/sentiment_compound_entropy_winter.png"
#fig.savefig(plot_name)

fig.show()

# %%
# Now from 15.12 - now
#mask = (df['date'] >= '2020-12-15')
#winter_df = df.loc[mask]

# %%
#winter_df["smooth_compound2"] = gaussian_kernel(winter_df["centered_compound"], sigma = 1, fwhm = 1000)

# %%
#winter_df = pd.read_csv("winter_df_sent_entropy.csv")
#winter_df["date"] = pd.to_datetime(winter_df["date"])

# %%
fig, ax1, palette = set_base_plot_settings(fontsize=30, if_palette = True)

ax1 = sns.lineplot(x="date", y="centered_compound", 
                   label="Daily", color = palette[2],
                   alpha = 0.30,
                   linewidth = 3, data = df)

ax1 = sns.lineplot(x="date", y="s2000_compound", 
                   label="Smoothed", color = palette[5],
                     linewidth = 3, data = df)

fig, ax1 = set_late_plot_settings(if_dates = True)

# Color the bg
plt.axhspan(0, 0.25, color = "green", facecolor='0.2', alpha=0.1)
plt.axhspan(0, -0.25, color = "red", facecolor='0.2', alpha=0.1)

plt.axvline(dt.datetime(2021, 3, 11), color=palette[5])
plt.text(x = dt.datetime(2021, 3, 12), # x-coordinate position of data label, adjusted to be 3 right of the data point
 y = 0.2, #winter_df[winter_df["date"] == "2021-03-11"]["compound"].reset_index(drop=True)[0], # y-coordinate position of data label, to take max height 
 s = 'AstraZeneca halted', # data label
 color = palette[5])

ax1.legend_.remove()
ax1.set(ylim=(-0.25, 0.25))

plot_name = "fig/sentiment_compound_winter.png"
#fig.savefig(plot_name)

fig.show()
# Out:
# /home/commando/maris/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   from ipykernel import kernelapp as app
# /home/commando/maris/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   app.launch_new_instance()

# %%
# Add important dates as scatterplot
dates = ["2020-12-21", "2020-12-27", 
         "2021-01-06", "2021-01-29",
        "2021-03-11", "2021-03-25", "2021-04-14"]
labels = ["Pfizer godkendt", "Vaccinationer påbegyndes",
         "Moderna godkendt", "AstraZeneca (AZ) godkendt",
         "AZ på pause", "AZ pause forlænges", "AZ udgår"]
labels = ["Pfizer approved", "Vaccinations begin",
         "Moderna approved", "AstraZeneca (AZ) approved",
         "AZ halted", "AZ further halted", "AZ withdrawn"]

dates_df = df[df["date"].isin(dates)]

# %%
dates_df = dates_df.groupby("date").mean().reset_index()
dates_df["labels"] = labels
dates_df["date"] = pd.to_datetime(dates_df["date"])
dates_df["date1"] = pd.DatetimeIndex(dates_df.date) + pd.DateOffset(1)

pos_dates_df = dates_df[0:4]
neg_dates_df = dates_df[4:].reset_index(drop=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt

matplotlib.rc('ytick', labelsize=20)
matplotlib.rc('xtick', labelsize=20)

themes.theme_minimal(grid=False, ticks=False, fontsize=18)
a4_dims = (25,15) #(11.7, 8.27)
#          0 black      1 orange  2 L blue   3 green    4 L orange  5 D blue  6 D orange 7 purple
palette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]

fig, (ax0) = plt.subplots(1,1, figsize=a4_dims)
sns.set(font_scale = 2)

ax0 = sns.histplot(x="date", alpha = 0.4,
                   color = palette[7],
                   bins = len(df["date"].unique()), element="step",
                  data = df)

ax0.xaxis_date()
date_form = mdates.DateFormatter("%d-%m")
ax0.xaxis.set_major_formatter(date_form)

ax1 = ax0.twinx()

ax1 = sns.lineplot(x="date", y="centered_compound", 
                   color = palette[2],
                   alpha = 0.20,
                     linewidth = 3, data = df)

ax1 = sns.lineplot(x="date", y="smooth_compound", 
                   color = palette[5],
                     linewidth = 4, data = df)

x_coordinates = dates_df["date"]
y_coordinates = dates_df["smooth_compound"]

plt.scatter(x_coordinates, y_coordinates, color="none", edgecolor="red",
           s = 500, linewidths = 3) 

for i in range(pos_dates_df.shape[0]):
    plt.text(x = pos_dates_df.date1[i], y = pos_dates_df.smooth_compound2[i]+0.007,
             s = pos_dates_df.labels[i],
             fontdict = dict(color=palette[0],size=25),
             bbox = dict(facecolor="white",alpha=0.5))
    
for i in range(neg_dates_df.shape[0]):
    plt.text(x = neg_dates_df.date1[i], y = neg_dates_df.smooth_compound2[i]-0.014,
             s = neg_dates_df.labels[i],
             fontdict = dict(color=palette[0],size=25),
             bbox = dict(facecolor="white",alpha=0.5))#palette[3]
    
plt.axvline(dt.datetime(2021, 1, 1), color="grey")
plt.axhline(0, color="grey", linewidth = 3)

ax1.set(xlabel="", ylabel = "Compound sentiment of 'vaccin*' mentions")
ax1.xaxis.get_label().set_fontsize(30)
ax1.yaxis.get_label().set_fontsize(30)
ax0.set(xlabel="", ylabel = "Count of 'vaccin*' mentions")
ax0.xaxis.get_label().set_fontsize(30)
ax0.yaxis.get_label().set_fontsize(30)

ax1.grid(linestyle='-', linewidth=0.5, which= "both")

# Define the date format
ax1.xaxis_date()
date_form = mdates.DateFormatter("%d-%m")
ax1.xaxis.set_major_formatter(date_form)

#ax0.set(ylim=(0, 5000))
ax1.set(ylim=(-0.15, 0.15))


plot_name = "fig/sentiment_compound_labelled_winter.png"
fig.savefig(plot_name, bbox="tight", dpi=300)

fig.show()

# %%
matplotlib.rc('ytick', labelsize=20)
matplotlib.rc('xtick', labelsize=20)

themes.theme_minimal(grid=False, ticks=False, fontsize=18)
a4_dims = (25,15)
#          0 black      1 orange  2 L blue   3 green    4 L orange  5 D blue  6 D orange 7 purple
palette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]

fig, (ax1) = plt.subplots(1,1, figsize=a4_dims)
sns.set(font_scale = 2)

ax1 = sns.lineplot(x="date", y="centered_compound", 
                   #label="", 
                   color = palette[2],
                   alpha = 0.30,
                     linewidth = 3, data = df)

ax1 = sns.lineplot(x="date", y="smooth_compound", 
                   label="Sentiment", 
                   color = palette[5],
                     linewidth = 4, data = df)

x_coordinates = dates_df["date"]
y_coordinates = dates_df["smooth_compound"]

plt.scatter(x_coordinates, y_coordinates, color="none", edgecolor="red",
           s = 500, linewidths = 3) 


ax1 = sns.scatterplot(x="date", y="smooth_compound",
                      s = 500, marker = "o",
                      #facecolors='none', 
                      edgecolors='red',
                      color = palette[0],
                     data = dates_df, ax = ax1)

plt.scatter(x="date",y="smooth_compound", marker = "o", s=7,
            #markeredgewidth=1,markeredgecolor="g",
            #markerfacecolor="None", 
            data = dates_df)

markers = [plt.Line2D([0,0],[0,0], markeredgecolor="red",
                      marker='o', markerfacecolor='none',
                      mew=0.3,
                      linestyle='')]
           # for key in pal]

for i in range(dates_df.shape[0]):
    plt.text(x=dates_df.date[i],y=dates_df.smooth_compound2[i]+0.004,
             s=dates_df.labels[i],
             fontdict=dict(color=palette[0],size=20),
             bbox=dict(facecolor=palette[3],alpha=0.4))
    
plt.axvline(dt.datetime(2021, 1, 1), color="grey")

# Color the bg
plt.axhspan(0, 0.15, color = "green", facecolor='0.2', alpha=0.1)
plt.axhspan(0, -0.15, color = "red", facecolor='0.2', alpha=0.1)


# 'solid', 'dashed', 'dashdot', 'dotted'
ax2 = ax1.twinx()
ax2 = sns.lineplot(x="date", y="entropy", 
                   #label="Daily", 
                   color = palette[1],
                   alpha = 0.30,
                     linewidth = 3, 
                   linestyle = "dotted",
                   data = df)


ax1.set(xlabel="", ylabel = "Sentiment")
ax1.xaxis.get_label().set_fontsize(30)
ax1.yaxis.get_label().set_fontsize(30)
ax2.set(xlabel="", ylabel = "Entropy")
ax2.xaxis.get_label().set_fontsize(30)
ax2.yaxis.get_label().set_fontsize(30)

ax1.grid(linestyle='-', linewidth=0.5, which= "both")
ax2.grid(False)

# Define the date format
ax1.xaxis_date()
date_form = mdates.DateFormatter("%d-%m")
ax1.xaxis.set_major_formatter(date_form)

ax2 = sns.lineplot(x="date", y="smooth_entropy", 
                   label="Entropy", 
                   color = palette[6],
                   #alpha = 0.30,
                   linestyle = "dotted",
                     linewidth = 5, data = df)


fig.suptitle("Sentiment and entropy of mentions of 'vaccin*'. 2021", size = "40")

ax1.legend(loc=2)
plt.legend(markers, numpoints=1)

ax2.legend(loc=1)

plot_name = "fig/sentiment_compound_entropy_winter.png"
fig.savefig(plot_name)

fig.show()
# Out:
# /home/commando/maris/lib/python3.6/site-packages/ipykernel_launcher.py:57: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
# /home/commando/maris/lib/python3.6/site-packages/ipykernel_launcher.py:58: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.

# %%
#winter_df.to_csv("winter_df_sent_entropy.csv", index=False)

# %%
wfreq_df = pd.read_csv("wfreq_df.csv")
wfreq_df["date"] = pd.to_datetime(wfreq_df["date"])

# %%
import pandas as pd
import matplotlib.pyplot as plt

matplotlib.rc('ytick', labelsize=20)
matplotlib.rc('xtick', labelsize=20)


themes.theme_minimal(grid=False, ticks=False, fontsize=18)
a4_dims = (25,15) #(11.7, 8.27)
#          0 black      1 orange  2 L blue   3 green    4 L orange  5 D blue  6 D orange 7 purple
palette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]

fig, (ax1) = plt.subplots(1,1, figsize=a4_dims)
sns.set(font_scale = 2)
#ax1 = sns.lineplot(x="date", y="compound", 
#                   label="Daily", color = palette[2],
#                     linewidth = 3, data = winter_df)


ax1 = sns.lineplot(x="date", y="centered_compound", 
                   #label="", 
                   color = palette[2],
                   alpha = 0.30,
                     linewidth = 3, data = winter_df)

ax1 = sns.lineplot(x="date", y="smooth_compound2", 
                   label="Sentiment", 
                   color = palette[5],
                     linewidth = 3, data = winter_df)


# 'solid', 'dashed', 'dashdot', 'dotted'
ax2 = ax1.twinx()


ax2 = sns.lineplot(x="date", y="nr_of_tweets", 
                  color = palette[0], 
                   linestyle = "dotted",
                   alpha = 0.30,
                   #label = "Number of tweets",
                     linewidth = 3, data = wfreq_df)

ax2 = sns.lineplot(x="date", y="smooth", 
                  color = palette[0], 
                   label = "Number of tweets",
                   #linestyle="dotted",
                     linewidth = 3, data = wfreq_df)


ax1.set(xlabel="", ylabel = "")
ax1.xaxis.get_label().set_fontsize(40)
ax1.yaxis.get_label().set_fontsize(40)

ax1.grid(color='grey', linestyle='-', linewidth=0.5, which= "both")

# Define the date format
ax1.xaxis_date()
date_form = mdates.DateFormatter("%d-%m")
ax1.xaxis.set_major_formatter(date_form)

#fig.suptitle("Sentiment and entropy of mentions of 'vaccin*'. 2021", size = "40")
#plot_name = "fig/sentiment_compound_entropy_winter.png"
#fig.savefig(plot_name)

fig.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

matplotlib.rc('ytick', labelsize=20)
matplotlib.rc('xtick', labelsize=20)


themes.theme_minimal(grid=False, ticks=False, fontsize=18)
a4_dims = (25,15) #(11.7, 8.27)
#          0 black      1 orange  2 L blue   3 green    4 L orange  5 D blue  6 D orange 7 purple
palette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]

fig, (ax1) = plt.subplots(1,1, figsize=a4_dims)
sns.set(font_scale = 2)
#ax1 = sns.lineplot(x="date", y="compound", 
#                   label="Daily", color = palette[2],
#                     linewidth = 3, data = winter_df)


ax1 = sns.lineplot(x="date", y="entropy", 
                   #label="", 
                   color = palette[1],
                   alpha = 0.30,
                     linewidth = 3, data = winter_df)

ax1 = sns.lineplot(x="date", y="smooth_entropy", 
                   label="Entropy", 
                   color = palette[6],
                     linewidth = 3, data = winter_df)


# 'solid', 'dashed', 'dashdot', 'dotted'
ax2 = ax1.twinx()


ax2 = sns.lineplot(x="date", y="nr_of_tweets", 
                  color = palette[0], 
                   linestyle = "dotted",
                   alpha = 0.30,
                   #label = "Number of tweets",
                     linewidth = 3, data = wfreq_df)

ax2 = sns.lineplot(x="date", y="smooth", 
                  color = palette[0], 
                   label = "Number of tweets",
                   #linestyle="dotted",
                     linewidth = 3, data = wfreq_df)


ax1.set(xlabel="", ylabel = "")
ax1.xaxis.get_label().set_fontsize(40)
ax1.yaxis.get_label().set_fontsize(40)

ax1.grid(color='grey', linestyle='-', linewidth=0.5, which= "both")

# Define the date format
ax1.xaxis_date()
date_form = mdates.DateFormatter("%d-%m")
ax1.xaxis.set_major_formatter(date_form)

#fig.suptitle("Sentiment and entropy of mentions of 'vaccin*'. 2021", size = "40")
#plot_name = "fig/sentiment_compound_entropy_winter.png"
#fig.savefig(plot_name)

fig.show()

# %%
sns.set_style("white")
winter_df["month"] = pd.to_datetime(winter_df["created_at"], utc=True).dt.strftime('%Y-%m')
sns.boxplot(x = 'month', y='smooth_compound2', data = winter_df, color = palette[5]);

# %%
sns.set_style("white")
winter_df["month"] = pd.to_datetime(winter_df["created_at"], utc=True).dt.strftime('%Y-%m')
sns.boxplot(x = 'month', y='smooth_entropy', data = winter_df, color = palette[6]);

# %%
import pandas as pd
import matplotlib.pyplot as plt

matplotlib.rc('ytick', labelsize=20)
matplotlib.rc('xtick', labelsize=20)


themes.theme_minimal(grid=False, ticks=False, fontsize=18)
a4_dims = (25,15) #(11.7, 8.27)
#          0 black      1 orange  2 L blue   3 green    4 L orange  5 D blue  6 D orange 7 purple
palette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]

fig, (ax1) = plt.subplots(1,1, figsize=a4_dims)
sns.set(font_scale = 2)
#ax1 = sns.lineplot(x="date", y="compound", 
#                   label="Daily", color = palette[2],
#                     linewidth = 3, data = winter_df)


ax1 = sns.lineplot(x="date", y="centered_compound", 
                   #label="", 
                   color = palette[2],
                   alpha = 0.30,
                     linewidth = 3, data = winter_df)

ax1 = sns.lineplot(x="date", y="smooth_compound2", 
                   label="Sentiment", 
                   color = palette[5],
                     linewidth = 3, data = winter_df)


# 'solid', 'dashed', 'dashdot', 'dotted'
ax2 = ax1.twinx()
ax2 = sns.lineplot(x="date", y="entropy_x", 
                   #label="Daily", 
                   color = palette[1],
                   alpha = 0.30,
                     linewidth = 3, 
                   linestyle = "dotted",
                   data = winter_df)


ax1.set(xlabel="", ylabel = "")
ax1.xaxis.get_label().set_fontsize(40)
ax1.yaxis.get_label().set_fontsize(40)

ax1.grid(color='grey', linestyle='-', linewidth=0.5, which= "both")

# Define the date format
ax1.xaxis_date()
date_form = mdates.DateFormatter("%d-%m")
ax1.xaxis.set_major_formatter(date_form)

# Color the bg
#plt.axhspan(0, 0.25, color = "green", facecolor='0.2', alpha=0.1, ax=ax1)
#plt.axhspan(0, -0.25, color = "red", facecolor='0.2', alpha=0.1, ax=ax1)

#highlighted
plt.axvline(dt.datetime(2020, 12, 21), color="blue", linewidth=5)#palette[5])
plt.axvline(dt.datetime(2020, 12, 27), color="black", linewidth=5)#palette[5])
plt.axvline(dt.datetime(2021, 1, 6), color="green", linewidth=5)#palette[5])
plt.axvline(dt.datetime(2021, 1, 19), color="red", linewidth=5)#palette[5])
plt.axvline(dt.datetime(2021, 3, 11), color="red", linewidth=5)#palette[5])
plt.axvline(dt.datetime(2021, 3, 25), color="red", linewidth=5)#palette[5])
plt.axvline(dt.datetime(2021, 3, 11), color="red", linewidth=5)#palette[5])

#extra
plt.axvline(dt.datetime(2021, 2, 3), color="black")#palette[5])
plt.axvline(dt.datetime(2021, 2, 26), color="black")#palette[5])
plt.axvline(dt.datetime(2021, 3, 10), color="black")#palette[5])
plt.axvline(dt.datetime(2021, 3, 18), color="black")#palette[5])


#plt.text(x = dt.datetime(2021, 3, 12), # x-coordinate position of data label, adjusted to be 3 right of the data point
# y = 0.2, #winter_df[winter_df["date"] == "2021-03-11"]["compound"].reset_index(drop=True)[0], # y-coordinate position of data label, to take max height 
# s = 'AstraZeneca halted', # data label
# color = palette[5])

#plt.axvline(dt.datetime(2020, 12, 27), color=palette[5])
#plt.text(x = dt.datetime(2020, 12, 28), # x-coordinate position of data label, adjusted to be 3 right of the data point
# y = 0.15, #winter_df[winter_df["date"] == "2021-03-11"]["compound"].reset_index(drop=True)[0], # y-coordinate position of data label, to take max height 
# s = 'First vaccinations', # data label
# color = palette[5])

ax2 = sns.lineplot(x="date", y="smooth_entropy", 
                   label="Entropy", 
                   color = palette[6],
                   #alpha = 0.30,
                   linestyle = "dotted",
                     linewidth = 4, data = winter_df)

fig.suptitle("Sentiment and entropy of mentions of 'vaccin*'. 2021", size = "40")
#ax1.set_title('Level 1', fontsize=30)

#ax1.legend_.remove()
#ax1.set(ylim=(-0.25, 0.25))

plot_name = "fig/sentiment_compound_entropy_winter.png"
fig.savefig(plot_name)

fig.show()

# %%
winter_df.sort_values("smooth_compound2").drop_duplicates("date")[0:10]
# Out:
#        index           created_at            id  \
# 48754  73361  2021-03-11 12:31:01  1.369989e+18
# 54323  79154  2021-03-20 08:51:45  1.373196e+18
# 54251  79082  2021-03-19 23:55:56  1.373061e+18
# 54746  79602  2021-03-21 00:00:58  1.373424e+18
# 50758  75439  2021-03-14 12:08:50  1.371071e+18
# 50633  75307  2021-03-13 23:48:00  1.370884e+18
# 48058  72636  2021-03-10 23:46:49  1.369797e+18
# 51047  75743  2021-03-15 00:14:11  1.371253e+18
# 49565  74200  2021-03-12 00:08:06  1.370165e+18
# 56647  81571  2021-03-24 06:55:36  1.374616e+18
#
#                                                     text search_keyword  \
# 48754  @Heunicke Kunne være interessant, at høre, hva...     ['vaccin']
# 54323  @martinnorling2 @harley_lund @TomJensen1966 Me...     ['vaccin']
# 54251  @JonasHerby Det er helt absurt at man bruger 3...     ['vaccin']
# 54746  @AliSufiDK lægevidenskaben bliver heldigvis be...     ['vaccin']
# 50758  @AndersGundelach @KarinVerland 1/ En test fang...     ['vaccin']
# 50633  @jyllandsposten Sut min pik. Jeg vil ALDRIG ta...     ['vaccin']
# 48058  @Stine2010 @RosenkrantzT Og hvad gør dig sårba...     ['vaccin']
# 51047  @Wirlander @LiseAndersen6 Okey det er så ikke ...     ['vaccin']
# 49565  Så faldt Venstre til patten. Så ved vi, at Ven...     ['vaccin']
# 56647  @bailey_hass @dybtuserioest @AliSufiDK Så skal...     ['vaccin']
#
#             date                                  mentioneless_text  \
# 48754 2021-03-11   Kunne være interessant, at høre, hvad en såda...
# 54323 2021-03-20     Men er de det?  Jeg er helt med på at der s...
# 54251 2021-03-19   Det er helt absurt at man bruger 30-50mio om ...
# 54746 2021-03-21   lægevidenskaben bliver heldigvis bedre og klo...
# 50758 2021-03-14    1/ En test fanger ikke alle smittede. Især i...
# 50633 2021-03-13   Sut min pik. Jeg vil ALDRIG tage den skide va...
# 48058 2021-03-10    Og hvad gør dig sårbar, og urolig for IKKE a...
# 51047 2021-03-15    Okey det er så ikke så lovende med mindre de...
# 49565 2021-03-12  Så faldt Venstre til patten. Så ved vi, at Ven...
# 56647 2021-03-24     Så skal der holdes corona party!   Jeg troe...
#
#                                                   text50  dupe50    neg  ...  \
# 48754   Kunne være interessant, at høre, hvad en såda...   False  0.025  ...
# 54323     Men er de det?  Jeg er helt med på at der s...   False  0.093  ...
# 54251   Det er helt absurt at man bruger 30-50mio om ...   False  0.000  ...
# 54746   lægevidenskaben bliver heldigvis bedre og klo...   False  0.000  ...
# 50758    1/ En test fanger ikke alle smittede. Især i...   False  0.000  ...
# 50633   Sut min pik. Jeg vil ALDRIG tage den skide va...   False  0.113  ...
# 48058    Og hvad gør dig sårbar, og urolig for IKKE a...   False  0.330  ...
# 51047    Okey det er så ikke så lovende med mindre de...   False  0.000  ...
# 49565  Så faldt Venstre til patten. Så ved vi, at Ven...   False  0.000  ...
# 56647     Så skal der holdes corona party!   Jeg troe...   False  0.153  ...
#
#        compound_7day_ave  centered_compound  centered_sentida  \
# 48754           0.161571           0.691499         -0.015138
# 54323          -0.040957          -0.588301         -0.006805
# 54251           0.069886           0.736899          0.082084
# 54746           0.143557           0.751399          0.250072
# 50758          -0.025671           0.013399         -0.047083
# 50633          -0.273986          -0.608801         -0.001644
# 48058          -0.081186          -0.732801         -0.213749
# 51047          -0.213800          -0.072301         -0.128749
# 49565          -0.184471          -0.072301         -0.051821
# 56647          -0.247414          -0.612601         -0.134922
#
#        normalized_afinn  centered_afinn         day  entropy_x  \
# 48754          0.526316        0.051484  2021-03-11   5.408284
# 54323          0.421053       -0.053779  2021-03-20   5.034004
# 54251          0.631579        0.156748  2021-03-19   4.915979
# 54746          0.736842        0.262011  2021-03-21   4.666055
# 50758          0.236842       -0.237989  2021-03-14   4.942740
# 50633          0.368421       -0.106410  2021-03-13   5.028114
# 48058          0.368421       -0.106410  2021-03-10   5.112934
# 51047          0.526316        0.051484  2021-03-15   5.087446
# 49565          0.473684       -0.001147  2021-03-12   5.094396
# 56647          0.394737       -0.080095  2021-03-24   4.964012
#
#        smooth_compound2  entropy_y  smooth_entropy
# 48754         -0.081171   5.408284        5.383832
# 54323         -0.072455   5.034004        4.937444
# 54251         -0.072093   4.915979        4.938981
# 54746         -0.061041   4.666055        4.915583
# 50758         -0.057775   4.942740        5.016861
# 50633         -0.057184   5.028114        5.020622
# 48058         -0.054972   5.112934        5.229466
# 51047         -0.054838   5.087446        5.023352
# 49565         -0.051972   5.094396        5.246185
# 56647         -0.047558   4.964012        5.235876
#
# [10 rows x 25 columns]

# %% [markdown]
# ## R squared value

# %%
from sklearn.metrics import r2_score

avg_compound = df.groupby("date").mean("centered_compound").reset_index()["centered_compound"]
avg_sentida = df.groupby("date").mean("centered_sentida").reset_index()["centered_sentida"]

ic(r2_score(avg_compound, avg_sentida))
# Out:
# ic| r2_score(avg_compound, avg_sentida): 0.507717187267411
# 0.507717187267411

# %%
from sklearn.metrics import r2_score

#coefficient_of_dermination = 
ic(r2_score(avg_compound, avg_sentida))

ic(r2_score(df["centered_compound"], df["centered_sentida"]))
ic(r2_score(df["centered_sentida"], df["centered_compound"]))

ic(r2_score(df["centered_compound"], df["centered_afinn"]))
ic(r2_score(df["centered_compound"], df["normalized_afinn"]))
ic(r2_score(df["compound"], df["normalized_afinn"]))
# Out:
# ic| r2_score(avg_compound, avg_sentida): 0.48660690541157314
# ic| r2_score(df["centered_compound"], df["centered_sentida"]): -0.07058358673082399
# ic| r2_score(df["centered_sentida"], df["centered_compound"]): -12.214899960624193
# ic| r2_score(df["centered_compound"], df["centered_afinn"]): -0.023248855211049912
# ic| r2_score(df["centered_compound"], df["normalized_afinn"]): -1.1269809860202926
# ic| r2_score(df["compound"], df["normalized_afinn"]): -0.8059487312276943
# -0.8059487312276943

# %%
df["compound"]
# Out:
# 22048   -0.4882
# 22049   -0.2500
# 22050    0.0000
# 22051    0.8221
# 22052    0.0857
#           ...
# 80861   -0.7580
# 80862    0.0000
# 80863    0.7804
# 80864   -0.3953
# 80865    0.1696
# Name: compound, Length: 58818, dtype: float64

# %%
# Data for knielbo
df0 = winter_df[["id", "created_at", "entropy", "centered_compound"]]
df1 = freq_df[["id", "created_at", "nr_of_tweets"]]

dff = pd.merge(df0, df1)

# %%
dff.to_csv("sent_entropy_vaccines.csv", index = False, header = True)

# %%
winter_df[winter_df["date"] == "2021-03-22"].reset_index()["text"][0]
# Out:
# '@heldigt Ja det er ude af proportioner at massevaccinere millioner af raske for at redde få udsatte. Det gør vi jo heller ikke med influenza. I DK er der to ud af 140000 med AZ der er døde med blodprop. Norge er oppe på fire eller fem.'

# %%
for tweet in range(0, len(winter_df[winter_df["date"] == "2021-03-22"])):
    print(winter_df[winter_df["date"] == "2021-03-22"].reset_index()["text"][tweet])
    print(" ------- ")
# Out:
# @heldigt Ja det er ude af proportioner at massevaccinere millioner af raske for at redde få udsatte. Det gør vi jo heller ikke med influenza. I DK er der to ud af 140000 med AZ der er døde med blodprop. Norge er oppe på fire eller fem.
#  -------
# @tv2newsdk Folk dør af disse vacciner i hobe tal i USA. Men ingen snakker om det, hvorfor ikke? Billedet er fra CDC's hjemmeside. Kig selv, det er offentlig tilgængeligt materiale. https://t.co/AQMxTkB8YL
#  -------
# @TaniaGroth Ja Sikkerheden ved Turbo udviklet Lægemidler  Gør de fritages for Erstatning   Ved uheldige Udfald i Hjælpen til Menneske heden   Lige som Dem. Der stikker kanylen i Folk  Har mulighed for at sige. Det er jo frivilligt at blive vaccineret   Vis skyld kunne Placeres ville ingen
#  -------
# @BMccrawe Uha.... det bør du vaccineres i mod 🙃😄
#  -------
# @JonasHerby Det underlige er, at EMA først skulle godkende den, før vi kunne og måtte få den. Og nu godkender EMA så vaccinen en gang til, men det stoler vi så ikke helt på.😳
#  -------
# @LasseTKrogsbll Vi er allerede i en meget hård lockdown. Og mener også risiko for gennedlukning er begrænset pga vaccinationsindsatsen og sæson - men selvfølgelig altid vigtigt at tage højde for at regeringen vælger at gøre noget skørt.
#  -------
# @DRNyheder Tid til “normalisering” alle festivaller med videre skal kunne afholdes som før Corona. Vi har ventet “lige lidt endnu” i over et år!  De gamle og svage er vaccineret og de unge får ikke engang symptomer. Desuden er det udendørs 90% af tiden, og i sommer perioden.  Vi må godt 🥳
#  -------
# @BertramWoodwork @TaMartinNielsen @tv2newsdk Ja og de snakker om år ude i fremtiden. Nye Vacciner forever. Det handler ikke om sundhed det er vi nød til at forstå allesammen. Det handler om kontrol af mennesker. Os. Og det hører ingen steder hjemme. Vi har en menneskelig pligt til at sige fra. 🙏🏼💜
#  -------
# @tv2newsdk Er vi ikke ved at være der hvor vi skal åbne helt op og erkende at mennesket mod naturen er en kamp som er tabt på forhånd.  Jeg har selv haft corona, jo vist det var slemt men jeg lever og er naturligt vaccineret.  Så om man dør MED corona eller af en blodprop..
#  -------
# @PernilleSnnich2 @dittekarina Ja. Men samtidig får vi at vide, at dødelighed af samme grund p.g.a f.eks Panodil er flerfold højere. En anden ting undrer mig, England bruger den vaccine, men har hørt om dødsfald p.g.a samme, fra England?
#  -------
# Opfinderen af teknologien til Moderna vaccinen - som i øvrigt er offentligt finansieret - siger i @nytimes at han ikke kan forstå hvorfor vi ikke samarbejder mere.   https://t.co/KjTythk1X3
#  -------
# EU og USA vil ikke tvinge selskaber til at dele teknologien bag vaccinerne.   Det ville gå ud over produktion og distribution, siger de.  Hvis nu bare der var et godt historisk eksempel på hvordan man kan dele patenter...  #dkpol #dkaid https://t.co/Zme9JwhSy6
#  -------
# @mikaelmilhoj ...fordi  1) USA's pandemi er ved at dø ud (vacciner?) 2) de tester vidt forskelligt (antal døde følges ret "pænt" i denne sæson)  https://t.co/7v44c7tzfK
#  -------
# @kristianleth Undtagen med EU og deres vaccine bestilling. Det er jo indtil videre ikke nok vacciner. At nogen lande sikrede sig, uden tanke på andre, alle de vacciner de kunne få, betyder andre må vente.
#  -------
# Vi skal ikke have coronapas , hvad med dem som ikke ønsker at blive vaccineret og har grunde og dem der ikke kan tåle den. Skal de holde for andre fornøjligheder det helt skævt Pia O Dyhr.😕
#  -------
# Ændring af vaccineplan har ingen sundhedsfaglig baggrund. Ergo må #dkpol tage ansvar for at slette 200.000 danskere med øget risiko i prioritering af #coronavaccine #sundpol.
#  -------
# @HeidiTurid @mariusknulst Dødsfald og bivirkninger flere måneder efter vaccination vil blive tilskrevet coronaen. Mange vaccinerede vil blive alvorligt syge og/eller dø, hvis de rammes af en anden virus end c19, fordi immunforsvarets uspecikke reagenser nu er blevet Covid-specifik. Immunforsvaret er væk
#  -------
# Ugens EU-spørgsmål: Indfører EU eksportrestriktioner mod UK på topmødet torsdag-fredag for at sikre EU flere vacciner? Eller formår bl.a Holland, med henvisning til vigtigheden til de globale forsyningskæder for vaccine, at blokere for et forbud? #eudk https://t.co/gah1jNDsVd
#  -------
# @CBrunsholm @MaiVilladsen Der benyttes vaccinepas allerede. Hvis du tager til mere eksotiske lande skal du have et med. Så det er allerede en reel ting og giver god mening.
#  -------
# Bavarian henter ordre på koppevaccine for trecifret millionbeløb   https://t.co/erzgLCIh1C
#  -------
# Når vi kigger ud i verden, mærker vi konsekvenserne af den europæiske vaccine-fiasko:  I onsdags så jeg en video fra Israel. Og jeg blev grebet af en vis misundelse og melankoli. Den vaccinerede fremtids offentlige liv i al sin gakkethed. #covid19dk   https://t.co/yigAen85hN
#  -------
# Cut til USA, hvor Biden må sende en venlig tanke til sin forgænger, hvis administration har landet de aftaler, der gør at han kan love alle amerikanere et vaccine-tilbud per 1. maj. Indtil da er åbne butikker, cafeer, restauranter og ligefrem natklubber normalen.
#  -------
# I øvrigt en fin ironi, som jeg ikke har set nogen medier skrive om: Ligesom Trump tog æren for den lave arbejdsløshed og det opsving, Obamas økonomiske politik medførte, kan Biden lige nu sole sig i Trumps succes med at have handlet hurtigt på vaccinerne. Hvor var dén leder i WA? https://t.co/PWXXqFxEsa
#  -------
# I kampen for vaccine oplysning er https://t.co/I8aJArbaQW en super vigtig forening, de støtter også med advokat bistand hvis dig eller dit barn får bivirkning af vacciner og udgiver et medlemsblad. Støt op og bliv medlem👍@vaccinationDK  #kobjælder #covid19dk #dkpol #dkmedier
#  -------
# @nissen_bodil Der er ingen sammenhæng. Minkmutation smittede naturligvis ligeså meget og var ligeså farlig som den almindelige Corona. Det afgørende var om den var mere resistent overfor antistoffer og en fremtidig vaccine, som var begrundelsen for at regeringen gik i panik.
#  -------
# @JohannesSkov Tænker Nej !   Når folk dør er det normalt at der kommer en skepsis’s hos bruger af et medicinsk præpareret! Så hvis det frigives tror jeg ikke jeg er alene om st sige nej til 2 vaccine stik, og så er der jo overskud til de personer der gerne vil
#  -------
# Hver dag (næsten) tjekker jeg vaccinestatus her i Finland  På en måde er det opløftende, når man ser at 730,000 har fået første dosis  På en anden måde er det lidt nedslående når man ser at hvis vaccinetakten ikke blir hurtigere så er vi på 70% i September og 100%til juleaften! https://t.co/gXpQWYGd0r
#  -------
# Ældre og syge bør have frit vaccinevalg, mener organisationer https://t.co/2NWDXARPtV https://t.co/2Icr0VeZz5
#  -------
# @Lisbethkbraun @KimLiveDK @DRNyheder Alle. Ligesom alle andre vira. Det vi skal styre efter er graden af svær sygdom. Den er allerede kraftig minimeret gennem vacciner. Derudover har ca. 10 naturlig immunitet.
#  -------
# Er man lidt træt af lockdown, kan jeg varmt anbefale at købe flybilletter. Okay, måske forsinkes vaccinerne igen, så jeg ikke kan rejse, men *muligheden*, *drømmen* om at forlade postnummeret … ahhhh
#  -------
# @tv2newsdk Sæt vaccinerne til salg. Så må folk selv tilvælgd dem. Med mindre man er kommunist, er det faktisk den oplagte løsning.
#  -------
# 2/3 Ifølge Daily Telegraph og andre har EU ikke godkendt AstraZenecas fabrik i Holland endnu til levering af vacciner.   Forventes indenfor få dage. Ved ikke, hvorfor det har taget så længe for EU at godkende den...? @OleRyborg @mikaelmilhoj  https://t.co/h2cVzNjuwO https://t.co/Tc9zJJZyxq
#  -------
# @georgeambush @MaiVilladsen Øh, fordi den politiske Corona-situation betyder, at man skal vaccineres igen og igen. Det går aldrig væk.
#  -------
# Igen - hvorfor støtter DK ikke #tripswaiver,   så ALLE kan få afgang til vacciner, behandlinger og udstyr til Covid-19?
#  -------
# Før markedet åbner: Ordre og vaccinehåb kan løfte Bavarian i rødt marked https://t.co/OWMAQodg0R
#  -------
# @sur_mann Altså ligesom der altid har været krav/tvang om forskellige vacciner, for at komme til forskellige lande? Eneste forskel er bare, at der er så meget mere fokus på det nu.  Alle valg kommer med konsekvenser. Men faktum er, at der er et valg og dermed ikke tale om tvang.
#  -------
# @MaiVilladsen Det burde slet ikke indføres. Vi er en familie på fem som på ingen måde kommer til at lade os vaccinere mod covid. Derudover kender jeg mange som heller ikke vil. Det kommer til at skade samfundet, bare vent og se.
#  -------
# @RiggeNormark @NorremarkDK Altså på et eller andet tidspunkt har de vacciner der indgår i børnevaccineprogrammet jo også været testet på børn
#  -------
# @RememberMorfar @MaiVilladsen Som udgangspunkt bliver det "kultur-livet", hvilket højst sandsynligt vil sige forlystelser, koncerter etc. Man må håbe at rigtig mange, selv dem som lader sig vaccinere, vælger ikke at støtte den slags segregation. Når der tabes penge skal de nok komme på andre tanker.
#  -------
# @AsmundsenMorten ..samtidig med det kan du stadig smitte og videresmitte selvom du har modtaget en vaccine. Så det krav, den tvang som bliver sat op er totalitær og unødvendig. Hvis man vil beholde vores nuværende samfundsmodel.
#  -------
# @SaitoJanus @MaiVilladsen Der er temmelig stor forskel på at skulle have (eller anbefales) en vacc for gul feber i eksotiske egne og så at skulle vise et coronapas (ikke vaccinepas) for at komme på fx restaurant i DK. Det første giver mening, det andet synes jeg ikke gør. Du blander æbler og pærer. https://t.co/Mt2PRBWp7A
#  -------
# AstraZeneca-vaccinen er nu testet i USA. Her finder man en effektivitet på 79% mod symptomatisk COVID-19, og 100% mod slemme sygdomsforløb.   https://t.co/lRIzMrylGJ #covid19dk #dkpol https://t.co/bvdm3u025K
#  -------
# @mikaelmilhoj Man må håbe vi genoptager vaccination på torsdag!
#  -------
# Mange ældre er virkelig utrygge efter megen negativ omtale af AZ; @aeldresagen bekymret for, at alt for mange forbliver uvaccinerede, hvis de pga stor utryghed siger nej tak til AZ - det vil være rigtig skidt for folkesundhed @Rhamfeldtp @SSTSundhed @LMSTdk @Heunicke https://t.co/kJu9GLRRwl
#  -------
# @CBrunsholm @MaiVilladsen Nej det er mere dig som blander noget ind, som ik er et problem. Princippet med corona/vaccinepas er det samme. Du skal dokumentere, at du er vaccineret og derved ikke en stor fare for den almene sundhed. Har svært ved at se problemet at vise en app at man er vaccineret.
#  -------
# @tv2newsdk Hvis der skal være et valg må det gælde alle borgere. Er det forøvrigt ikke snart vores tur, syntes kun det er syge og ældre der bliver vaccineret?
#  -------
# @sillern Jeg synes, at det siger meget om begge lande, at det officielle mål i 🇩🇰 er inden juli, mens det i 🇫🇮 er inden jul.  Samme tilgang af forsyninger, samme (næsten synkront!) vaccinationstakt, men *helt* andet mål.   Lave forventninger -> Tilfreds befolkning...?
#  -------
# Igår fik jeg min første Pfizer vaccination mod covid 19. Den 14. April skal jeg have den anden. Men sikke et bøvl med at komme ind og få en tid.  Hav tålmodighed og F5 x 100!
#  -------
# @PoulHoi Kom så i gang med de vaccinationer DK.....! #CovidVaccine
#  -------
# @DavidTrads Tror nu den tidslinje bliver revideret snart.. Da jeg faktisk tror at mange ikke vil have en bestemt vaccine..
#  -------
# @SaitoJanus @MaiVilladsen Hvad så hvis man ikke er vaccineret? Så er det jo et problem og derfor er det heldigvis ikke et vaccinepas, men et coronapas der er tale om. Dvs negativ test eller antistoffer også godtages.
#  -------
# @sillern Så man vil vacciner alle over 16 år i Finland. Galimatias...
#  -------
# Tak, @PerLarsenC @KonservativeDK for dit tilsagn, hvis man er utryg ved AstraZ vaccinen, skal man have mulighed for at få tilbudt en anden vaccine.  #dkpol #COVID19Vaccine #sst @Heunicke   Ældre og syge bør have frit vaccinevalg, mener organisationer https://t.co/OuQ5iS8pHG
#  -------
# Det er  oplagt, at @apotekerne tager del i at coronavaccinere. Det var der enighed om, da Frank Schmidt-Hansen og @NielsFlemming01 @KonservativeDK var på besøg på Rødding Apotek https://t.co/Xsk0gWmfNk #sundpol
#  -------
# @ppkzd siger i Eftertryk, hvad der må siges. Israel er efter Geneve Konventionen forpligtet til at sikre vaccine i de besatte områder. At afskrive den realitet som antisemitisk er propaganda.   En ofte brugt korrespondent fortier konsekvent forpligtelsen https://t.co/0rC093iirY
#  -------
# @politiken Vi er i slutningen af marts. Smittetallene har været stabile i 50 dage, på trods af, at B117 er gået fra 20% - 100%. Vi vaccinerer (11% har delvis immunitet derigennem) og ca. 10% har naturlig immunitet.   Indlæggelser er faldende og dødsfald er 5X lavere end ved influenza.
#  -------
# Åbning i 14-dagesbølger, fokus på skolebørn og liberale erhverv først. Ny fase med fuld genåbning, når 50+ er vaccinerede inkl klog brug af coronapas. Opfølgning med genopretning på trivsel, økonomi og sundhed. Godt @venstredk plan bærer ind i forhandling: https://t.co/BMiZFzy9bk
#  -------
# @MarcStergaard @mpbdavidsen Et ukonkret svar, jeg ikke blev klogere af.  Resultaterne bidrager ikke med nyt. Der var kun ~21k deltagere, der fik vaccinen. De sjældne bivirkninger der pt undersøges, vil man ikke kunne forvente at se. Så safety-delen er værdiløs i den kontekst.
#  -------
# I Nyhederne kl 21.00 på DR i går aftes, bragtes et langt indslag om AdaptVac, den danskudviklede covid-vaccine, som nu testes på en lille grp mennesker i Holland. Desværre fik vi IKKE historien om, hvordan @regeringen afviste at støtte udviklingen af vaccinen.
#  -------
# Det er efter min mening en kæmpe fadæse, at @regeringDK lod den chance gå deres næse forbi. For vi får brug for vacciner, der kan give længere, bredere og mere varig immunitet. Og det kan den danske vaccine potentielt. “Big mistake. Huge!”  https://t.co/IKOyNg393B
#  -------
# @AndersFaurby @mvinaes @LasseTKrogsbll Det er bare lige det, at vi passer på en meget lille % del, de der endnu ikke er vaccineret, men på bekostning af mange små selvstændige, de pakker de får er langt fra tilstrækkeligt til at holde dem ovenvande. Meget af de løsninger, der er fra staten, er lån.
#  -------
# @mikaelmilhoj @Benjaminjochum Sydafrika har taget AZ vaccinen helt ud af deres program pga. reduceret effekt mod den sydafrikanske variant.
#  -------
# @Ullegaard @JanEJoergensen @venstredk Havde stået til jer var alt åbnet for længst og vi havde stået i en helt anden situation end vi har nu, nej vi har ikke brug for en borgerlig regering hverken liberal eller de fra højrefløjen. Hvad vil I gøre når mange af os ikke vil vaccineres med AstraZeneca ?
#  -------
# @JanEJoergensen Hvorfor er man pr. definition en tosse, når man er imod vaccinen? Det forekommer meget sort/hvidt.
#  -------
# @tv2newsdk Sverige har ikke stoppet Astra/Zeneca vaccinen, og firmaet er delvist Svensk, hvorfor vinkler i ikke dette? dårlig journalistik
#  -------
# To dør af blodpropper i Norge efter vacciner med AstraZeneca  https://t.co/QB3MSYkRJ8
#  -------
# Det har absolut ikke været uden bump på vejen, men det går fremad for vaccineproduktionen i EU og der er grund til optimisme ❤️💪🇪🇺 #eudk
#  -------
# Stort amerikansk studie af AstraZeneca-vaccinen med virkelig gode resultater! #covid19 https://t.co/V4fxrUqZj8
#  -------
# Hvordan skaffer vi flere coronavacciner? Hvordan holder vi middelhavet rent for plastik? Og kan Parlamentet få Kommissionen til at aktivere retsstatsmekanismen mod Polen og Ungarn? Det er på programmet i denne uge i Europa-Parlamentet. Læs mere her: https://t.co/CFpV50A6zv #eudk
#  -------
# @HoghSorensen @TorbenJessen3 @SSTSundhed Der er ingen, der ved hvad den vaccine gør ved os på sigt, at tro den vil redde nogen er absurd, når vi taler en en dødsrate, som ved en mellemhård influenza og med lignende forløb. Samtidig bliver ikke alle vaccinebivirkninger indrapporteret, så vi kender ikke det reelle billede
#  -------
# Vacciner: stadig ulemper i Cremona, kalder Asst borgere - Ultima Ora. Men dette viser Cremona, at han har respekt for alt.
#  -------
# I dag skulle jeg have haft anden og sidste covid-vaccine. Jeg har 100 procent tillid til danske sundhedsmyndigheder. Alligevel er det svært ikke at blive påvirket af alt den omtale AstraZeneca får i disse uger.
#  -------
# Brug af offentlig trafik er faldet med 90%. Desværre er der nok brug for mere end vacciner til at få alle til at vende tilbage. @DanskIndustri kommer med forslag til hvad der kunne prioriteres. DI: Sådan får vi danskerne til at tage bus og tog igen https://t.co/aJqVTU17oQ
#  -------
# @AnnetteGregers Jeg har glædet mig SÅ meget til at blive vaccineret, og jeg er 100 procent for vacciner, men alt det der foregår lige nu har sgu skræmt mig. Jeg er stadig for vacciner, men synes der er ting der virker underlige med de symptomer folk rammes af. ØV altså.
#  -------
# @HolgerD88276957 Det er sindssygt, at de risikerer ikke at kunne forsvare sig, hvis der opstår mange bivirkninger. "They vaccinated 81% of the Israeli army indiscriminately."
#  -------
# :-( Den tur - her i @FT - bliver ikke glemt foreloebigt. Igen i hvilket univers er det de venner DK skal have i EU/verden @Statsmin? To korruptionssvaekkede hoejrenationale + ingen vacciner = 💩! 👍 til alt. flertal i @folketinget. #dkpol #dkmedier https://t.co/3TbfrohV2J https://t.co/B3cELjRl37
#  -------
# @AndrJens @mpbdavidsen Det jo det som er essensen i et lodtrækningsforsøg. Nogle modtager placebo, og andre modtager vaccinen, for at undersøge effekten. Havde studiet vist at en kritisk masse af dem som modtog vaccinen var blevet ramt af bivirkninger kontra dem som ikke modtog, kunne man være bekymret
#  -------
# @Robert01982387 @BDjup Jeg har blitt kalt anti vaxx bare fordi jeg har vært imot Kina virus vaccina siden det ble snakk om den i fjor . Men jeg har jo tatt andre vaksiner før og dattera mi har fått barnevaksiner så hvordan kan jeg være anti vaxx da lurer jeg på? 🧐
#  -------
# @stinuslindgreen @M_B_Petersen Husk nu den i forbindelse vaccine-passet. Og husk også at det bliver indført til sommer, hvor sæsonvirus sars-cov-2 stort set ikke er tilstede. Til efteråret er vi vaccineret. Samlet set er det svært at se pointen med passet, men nemt at se den indbyggede tvang i den forbindelse.
#  -------
# @BDyrekilde @Enhedslisten Tror faktisk ikke det er lovligt jvf. Den europæiske menneskeretskonvention. Der blev i jan 2021 underskrevet aftale om at ikke-vaccinerede IKKE måtte diskrimineres og/eller få begrænset bevægelsesfrihed. Hvorfor skriver ingen om det????
#  -------
# @HenrikPahuus @MFT1981 Og det gælder fra sommer, når sæsonvirussen ikke er der og efterår, når mange er vaccineret...???
#  -------
# 9000 blev glemt: Kræftramte og andre sårbare mangler vaccine-invitation - systemfejl kan være årsagen   https://t.co/1lBKQiAFjp
#  -------
# Spm vi stiller: Er timing af besøg af shp vigtigt og for hvad? Hvordan påvirker efterfødselsreaktioner familien, hvad betyder screening som shp tilbyder? Hvordan påvirker shp forældrenes adfærd (fx vacciner)? Hvilken rolle spiller shptilbud som forældrekurser? 6/n
#  -------
# Endnu en ny forklaring i vaccinesag i Middelfart: Først var der en liste, så var der ikke - og så var der alligevel https://t.co/hzECSDuc05 #fyensdk #fyn
#  -------
# Spurgt på gaden: Vil du sige ja til at blive vaccineret med AstraZeneca-vaccinen? https://t.co/YQca0BAX1J
#  -------
# Det undre mig at vi ikke for længst har haft en “COVID-19 Pas” app. Krydsning af grænser mv. havde været langt simplere.  Så ville der også være en mulighed for at lande kan åbne op for vaccinerede.   Frisører m.v. kunne åbne nogle timer kun til vaccinerede. #dkbiz #dkpol
#  -------
# @mikaelmilhoj Kunne der sættes fokus på vaccinationskalenderen. Hvordan ville det virke hvis fx Pfizer/Moderna fik 6 uger mellem interval. Det er mærkeligt at kun taler AZ men ingen taler interval og om ikke der kunne være større effekt ved at få større interval. 1/2
#  -------
# Så mange vacciner har følgende eksporteret: 🇺🇸: 0 🇬🇧: 0 🇪🇺: 41,6 millioner  Alligevel er det EU, der nu bliver anklaget for "vaccinenationalisme" og for at "opføre sig som et diktatur" af den britiske regering. Hykleri! 👎🏻 #dkpol #eudk
#  -------
# @AsmundsenMorten @sur_mann Morten...nævn mig én eneste sygdom/tilstand som har været et krav/tvang at blive vaccineret for FØR man tog afsted på ferie i  !??. Det kan du faktuelt IKKE, for f.eks de sidste 50 år, der har vacciner været en ANBEFALING fordi de lande ofte ikke har samme syn på "renhed" som os
#  -------
# @stinuslindgreen @M_B_Petersen Hvad med længere vaccine interval, så i stedet for 3 uger på Pfizer så gik til 6 uger. Brostrøm kaldte det vist i sin tid uetisk ikke at godkende 6 uger så man fik vaccineret flere hurtigere, men alligevel kører de med tre uger.
#  -------
# @mvinaes @LasseTKrogsbll Vi er så tæt på, at ældre og skrøbelige er vaccineret - i hvert fald 1 stik. Så hvorfor ikke være tålmodig, i blot kort tid, end at risikere dødsfald, senfølger - og ja, en endnu hårdere lockdown. Alle I raske og stærke har jo hele livet for jer igen - snart. Tænk på din næste.
#  -------
# @sur_mann Intet at være bekymret for. Hvis man fortsætter sin nægtelse af vacciner, og ikke lader sig tvinge inddirekte, så taber turiststederne STADIGVÆK penge, og så vil turistbranchen lægge pres på regeringer verden over, for at fjerne vaccinepas.
#  -------
# @mikaelmilhoj Ved du/man om danskere der tidligere har haft blodpropper vil kunne (“få lov til at”) vælge AstraZenica vaccinen fra her i DK hvis den (evt) genoptages?
#  -------
# @sgaarder @HaukLandsverk @KrosbyNatalia Det er derfor de er så tydelige på at det er meget sandsynlig at de som er vaccineret med AstraZeneca og (desværre) er afgået ved døden, er pga. vaccinen. Det er (igen fra det jeg læser) meget uvanlige komplikationer, som sjældent opstår under normale omstændigheder.
#  -------
# @mikaelmilhoj Jeg har godt nok svært ved at forstå sundhedsmyndighedernes ræsonnement i den her sag. Forsinkelsen og usikkerheden omkring vaccinen kommer til at koste dyrt. Hvorfor har vi i EU haft en meget længere godkendelsesproces af vaccinerne, hvis den alligevel ikke kan bruges til noget?
#  -------
# Jeg er helt enig - med den usikkerhed der hersker omkring AZ vaccinen, bør der være en mulighed for fravalg. Ellers risikerer vi at nogle ikke vil lade sig vaccinere. Ældre og syge bør have frit vaccinevalg, mener organisationer https://t.co/kEfIyze2qn
#  -------
# Fredericia får sit eget vaccinationscenter: Åbner for alle efter påske https://t.co/r8ajSklGPF
#  -------
# @SSTbrostrom Jeg har uden held forsøgt at finde data for hvordan kønsfordelingen har været ifm. testing af astra vaccinen inden den blev godkendt. Håber du kan hjælpe med den oplysning?
#  -------
# @LasseJuelLarsen @LotteRod @sofiecn Vi håber der ikke kommer en tredje bølge. Håb er godt men en robust plan er bedre. Hvis sæsoneffekten er mindre end vi tror eller hvis vaccinerne er forsinkede.
#  -------
# Jeg får immundæmpende medicin, hørte til i tidl. gruppe 10. Har haft langvarig bivirkning af tidl influenzavaccine. Jeg vil gerne covid-vaccineres men ikke med AZ. Håber @SSTSundhed lader den enkelte beslutte om man vil vaccineres med AZ. Ellers takker jeg nej til covid-vaccine
#  -------
# @MaiVilladsen Under 4 % af befolkningen har officelt været smittet med Covid-19 henover et helt år. Kan det virkelig retfærdiggøre et vaccinepas og *tvangsvaccination*?  https://t.co/Rz8VYS1fB2
#  -------
# @Heunicke @SSI_dk Hmm så du siger, at man skal lade sig vaccinere, selvom man har antistoffer? Det er sjovt
#  -------
# Nu bliver Aarhus' socialt udsatte vaccineret: Hjemløse får første stik onsdag https://t.co/zsSjrt6n8f
#  -------
# Kæmpe vaccinefejl: 9.000 patienter blev glemt https://t.co/NeVW6m5q2r
#  -------
# @MarcStergaard @mpbdavidsen Jeg tror ikke, at du forstår substansen. Sinus-trombose er en sjælden blodprop (vaccine eller ej), og man kan ikke forvente at finde et tilfælde i så lille en studiepopulation. DK har fx vaccineret over 140k med AZ, og kun få har oplevet denne bivirkning.
#  -------
# Aktier/middag: Bavarian flyver atter af sted efter ordre og vaccinehåb  https://t.co/GcYxKU9SEy
#  -------
# @sur_mann Vi skal bare huske på, at coronapas vil og skal være en midlertidig foranstaltning. Derudover passer den del med videresmitte ikke, nye studier viser tydeligt at sandsynligheden for at en vaccineret smittet andre er meget meget lille.
#  -------
# @VanBolderheij @LarsAFCA39 @Ermis__ @Dani_Congo_ livet før vacciner i mellemøsten be like
#  -------
# Regionsrådsformand: Pres på vaccinationsbestilling lettes https://t.co/oEXlEZlLqQ
#  -------
# @mikaelmilhoj @JohannesSkov 100%? Kan man det? I lægmandssprog siger de at ingen der har fået vaccinen får et slemt forløb eller ender på hospitalet?
#  -------
# Aktiestatus: Bavarian flyver atter af sted efter ordre og vaccinehåb https://t.co/fY0OWlKncG
#  -------
# @IbChristensen12 @realklitgaard @tv2newsdk @tv2nyhederne Jeg tror aldeles ikke på EMA, de løber biofarma selskabets ærinde. SST er lidt fanget i samme båd og derfor er det befriende, at professor Lars Østergaard siger, at det eneste rette er at forlænge pauseringen af AZ vaccinen.
#  -------
# @lars_ole @mortenhelveg Så kan du jo lade dig vaccinere med ingredienser.
#  -------
# @ms_MariaB @NNnicoj Begge lande EU-lande, der ikke får nok vacciner. https://t.co/Hz8FlB90kP
#  -------
# @MaiVilladsen Og den slutdato skal være når næsten alle er vaccineret. Hvis I ikke kan lave et pas til dem. der ikke har NemID og smartphone.
#  -------
# @eliashelfer @JohannesSkov Men det er i kliniske forsøg. Når man massevaccinerer, så vil det jo nok ske for nogle, men nok meget få
#  -------
# Hold nu op.  Så åben da i det mindste op for AZ vaccinen for alle os der gerne tar risikoen for "alvorlige bivirkninger", der vel at mærke er ca. 3x mindre end ved brugen af p-piller.  Jeg stiller mig hjertens gerne først i kø.  #dkpol https://t.co/XbHA7GSosd
#  -------
# @AndrJens @mpbdavidsen Jeg forstår hvad du mener nu, og der kan jeg godt se studiet ikke siger noget specifikt om den konkrete(mulige) sammenhæng mellem tilfælde af blodprop & AZ vaccinen. Om ikke andet er det dog et vidnesbyrd om at vaccinen er effektiv og sikker.
#  -------
# Hjernekassen på P1 Mandag d. 22. feb.  De nye coronavacciner. Peter Lund Madsen har ekspert Thomas Senderovitz i studiet. https://t.co/OaU8yRa1X5 Det fineste skønmaleri siden Guldalderen ! https://t.co/AnRNvtxBjs
#  -------
# Han kanske hann få sitt vaccinpass i alla fall...  Italian teacher dies hours after getting AstraZeneca vaccine https://t.co/2ZkwBNGVym
#  -------
# @nbm_1981 @Nancke87 @Annamidtgaard @voxmeter @Spolitik @KonservativeDK @venstredk Det gør vaccinerne
#  -------
# @JarleHeitmann Hvor får dere dette fra ? AstraZeneca vaccine is 79% effective against symptomatic Covid-19, company says https://t.co/KsrvadPdqN
#  -------
# @OleRyborg Generelt set er Franskmændene jo relativt vaccine forskrækkede. Så måske dem der er på ja siden, er så overbeviste at forskellen mellem vaccinerne er detaljer?
#  -------
# Jeg synes at AstraZeneca vaccinen skal fjernes fra det danske vaccineprogram !!!!!
#  -------
# mundbind er et krav i Guate og ingen ved om de overhovedet får råd til vacciner endnu!! men det er da lige meget når man er et klamt, beskidt, hvidt dreadlock-svin🤢🧘‍♀️🧘‍♂️🤮
#  -------
# @RiggeNormark @NorremarkDK Det skal selvfølglig gøres på en ordentlig måde, men tror 99% af verdens børn og forældre er meget glade for at vi har børnevaccinerne
#  -------
# @mortenhelveg @radikale Så mange vacciner har rusland 🇷🇺 eksporteret: 170.340.000 Så mange russiske vacciner er blevet produceret af andre lande: 318.000.000 Måske burde vi importere fra rusland hvis ikke vi kan vaccinere hurtigt nok selv?
#  -------
# @jyllandsposten Dårlig argument at blive ved at sejle rundt i mudder. Flere har fået vaccine og danskerne er gode til at passe på, restriktioner har virket, derfor er tallet 870 ikke nået , omtanke og klogskab fra blå, tak.
#  -------
# @ealeorah Så et billede af en kollegas søsters arm. Hun var indirekte presset for at tage vaccinen astra z. pga arbejdsplads. Kan sige at armen ikke så særlig køn ud. Fra fingerspids til albuen havde blå, gule og røde "baner" i parallel med musklernes form. +
#  -------
# #Vaccine, vaccinationstid, #vaccinepas - disse begreber sætter dagsordenen i den offentlige #corona-debat for tiden. Vi må håbe, at vi gør det rigtige og ikke mister modet i det nuværende vaccinationskaos, mener Nils Baum. https://t.co/pIE6HoUKlV
#  -------
# Det er jo ikke en hemmelighed, at briterne er langt foran os i vaccinationsprocessen. Det ses også tydeligt i deres løbende antistofstikprøver, hvor en meget stor andel af de +70-årige nu har beskyttelse mod COVID-19  Håber snart vi får et tilsvarende survey #covid19dk https://t.co/7ejX0r5bIH
#  -------
# @ungermann_lars @Nancke87 @Annamidtgaard @voxmeter @Spolitik @KonservativeDK @venstredk Jo. Havde man holdt åben som i Sverige og ladet smitten brede sig blandt dem som ikke er i risikogruppen ville størstedelen være immune og pandemien vil dø ud. Derefter kan dem i risikogruppen vaccineres.  @SorenSchifter har oversat: https://t.co/XeP6l5onLi
#  -------
# @SaitoJanus @MaiVilladsen Hvad EU måtte finde på bliver en fælles EU løsning og vil ligeledes heller ikke være et vaccinationspas, men også hvor test eller antistoffer tæller med.
#  -------
# Vi er ved at lægge sidste hånd på denne uges planlægning af hjemmevaccination af sengeliggende borgere. Tirsdag, onsdag og torsdag forventer vi at nå hjem til 400 borgere i Region Sjælland #Sundpol #COVID19dk https://t.co/D8Y7vol6tD
#  -------
# EU har ikke eksporteret noget som helst. Selskaber beliggende i EU har solgt vacciner til de købere som bød bedst. En virksomhed beliggende i EU er ikke EU.
#  -------
# @CBrunsholm @MaiVilladsen Det er jo faktisk det jeg gør. Et Coronapas viser bare om hvorvidt du har fået en vaccine eller ej - præcis som det er på mit vaccinationskort jeg har. Jeg tror også du skal se det at det netop formentlig indkorporeres i et vaccinepas som andre man skal vaccineres imod
#  -------
# Mens selvstændige bløder penge, unge "uddannes" hjemmefra, syge ser deres behandlinger udskudt og folk får pip i isolation, booker vaccinerede pensionister charterferier i Sydeuropa.   Er det bare mig, eller virker det lidt tonedøvt? #dkpol #COVID19dk https://t.co/bOATakB2Ly
#  -------
# Når alle over 50 er vaccineret, øh er det ikke gået op for Ellemann og de andre, at vi er mange der ikke har planer i den retning  https://t.co/F9sof3lFY7
#  -------
# @JacobRosenberg2 Ja, hvorfor ser hun sig ikke bare om i DK. Her har vi flere vaccinefabrikker - Israel har ingen!
#  -------
# @SteffenFrolund Kan du huske historien fra november om hvor billigt eu havde fået vaccinerne?
#  -------
# 🇮🇱Israel har fået styr på pandemien. Tallene falder stadig, selvom man er påbegyndt genåbningen. Vaccinerne gør deres arbejde. #covid19dk https://t.co/iPuKHXQ9SX
#  -------
# Altså - er det ikke helt tosset? Så mange samlet et sted - fra hver sin familie - fra hele landet. Og - de skal vel hjem på weekend/påske. Hvorfor ventede de ikke et par måneder - så flere er vaccineret? #dkpol #dkmedier https://t.co/SYpM9qv7cu
#  -------
# @SaitoJanus @CBrunsholm @MaiVilladsen Der bliver desværre ikke nogen “kort tid” passet indføres og gælder både test og vaccination. Jeg har ikke noget imod vaccination eller en fedt i my og næ, men det er dybt problematisk at du skal dokumentere din ret til frihed. Især nu passet mere har symbolsk betydning.
#  -------
# Social- og Ældreminister @Astridkrag drøftede genåbning og vejen tilbage til fællesskabet sammen med partnerskab på handicapområdet. En række emner var på dagsordenen: selvisolation, coronapas, bekæmpelse af ensomhed og mistrivsel, test og vaccine #dkhandicap #dksocial #Covid19dk https://t.co/ulVz1TAEgP
#  -------
# Oralt Covidvaccin På G  https://t.co/E9dS157dHs https://t.co/CmrNQeXNPO
#  -------
# @hansersej Der er ikke brug for beregninger. Pandemien er slut. Åbn alt. Intet kan belaste sundhedsvæsenet når så mange er vaccineret. Medierne må virkelig se at komme i omdrejninger i stedet for at være makrelkonen spinmaskiner. Ca 90.000 skal vaccineres for at død og indlæggelser går i 0
#  -------
# @Jonas00766621 @AliSufiDK Det var da et tåbeligt forslag. Så I vil have at regeringen skal forbyde private firmaer kan forhindre uønskede personer til deres arrangementer? Jeg holder med at private firmaers ret til selv at bestemme. Hvis de så ikke ønsker at se et vaccinepas, så kan de jo bare lade være.
#  -------
# Glæder mig til centre er åbne igen, men venter gerne lidt, indtil der er mere gang i vaccinationerne.. Børnene er vigtige og frisørerne med krav om mundbind/visir. #dkpol   https://t.co/TfzlPXWssU
#  -------
# @SteffenFrolund Det det for mig gør debatten svær, er twistet med coronapas. Vi har historisk stor frivillig tilslutning til vacciner, som kan rokkes ved. Vil folk lade sig vaccinere med A-Z, de evt (ubegrundet?) frygter for at få deres “liv” tilbage, og er det frivillighed?
#  -------
# @PHChess Ja, det lader sig desværre ikke gøre i DK, hvor ingen politikere tør lade sig vaccinere af frygt for beskyldninger om at hoppe foran i køen. Vi har derfor en statsminister - krisens vigtigste person, uanset hvad mon måtte mene om MF - der ikke er vacccineret. #ligheds-galimatias
#  -------
# @SteffenFrolund 2/ Jeg håber på mulighed A, men uden coronapas, så folk frivilligt kan vælge den fra eller til. Så tror jeg, at tilliden til vaccinen vil være højere, end hvis der kommer en indirekte tvang.
#  -------
# @data02 @mikaelmilhoj Hvis vi oversætter det til danske forhold (med usikkerheder) når ca 3 millioner er vaccineret åbnes landet helt?
#  -------
# @i7337i @tv2newsdk @tv2nyhederne Der er også doser på lager i Danmark. At man gemmer til 2. vaccination betyder ikke at de er ubrugte. Det er endnu ikke lykkedes Mette Frederiksen at købe én eneste ekstra dose. Kontaktede hun nogensinde kansleren for at høre om de “ubrugte” doser @tv2newsdk spurgte hende om?
#  -------
# Mandag har aldrig føltes bedre, for min mor har netop fået første stik med Corona-vaccinen ♥️😍🙏🏻  #letsbeatcorona
#  -------
# @JakobEllemann @SorenPape @Kristianthdahl @PernilleVermund @LarsSandahlS  #dkpol #dkbiz  Men hvorfor er antistof imod COVID19 i blod så vigtigt! Fordi  1) svarer til en "vaccination" imod COVID19  2) bruges i f t dødelighed  3) afgørende for om 3.bølge overhovedet er mulig i DK
#  -------
# @BDyrekilde @Enhedslisten Meget enig muligt det skal bruges ved udlandsrejser og enkelte begivenheder, men når alle ned til 50 år er vaccineret skal samfundet åbnes og restriktioner + pas smides væk. “New normal” nein danke.
#  -------
# @Goldtsche @CBrunsholm @MaiVilladsen Så du mener at fremvise et vaccinepas på grænsen til X land er at tage din frihed væk? Godt så.
#  -------
# Den REELLE risiko reduktion i Pfizer-vaccinen er 0,7%. Men dette tal rapporteres ikke ... man havde nær sagt naturligvis ikke. https://t.co/cB65TR8sP6
#  -------
# @aayddyaa @mikaelmilhoj Jeg ved ikke helt om de 50% er ud af den vaccinerbare befolkning (altså uden børn under 16). I så fald vil tallet i dk nok være 2-2,5 mio
#  -------
# @tv2newsdk ALLE slal have fri vaccine valg AstraZeneca slår dig ihjel 🤔 så den skal jeg da ikke have. Tilgengæld er der vaccine TVANG for uden vaccine ingen frihed ingen rejser😏
#  -------
# Please don’t, pensionister. I behøver ikke bruge jeres vaccine som anledning til at pisse på klimaet. Det kan I fint lade rejsebranchen stå helt ...sammen med landbrugene om. https://t.co/lSvjQIt5Bi
#  -------
# AZN-pausen kan mærkes på vaccinationstempoet. To dage i træk med under 10.000 stik.   Vi har vist cirka 30.000 Pfizer-vacciner og 7.000 Moderna-vacciner (taget højde for reservationer) tilbage, så vi skal glæde os til større Pfizer-leverancer de kommende uger #covid19dk #dkpol https://t.co/wjIhRG4fxL
#  -------
# Status på vaccinationer i Danmark 🇩🇰  636.664 er påbegyndt deres vaccination og har fået det første stik. Det svarer til 10,9 % af befolkningen.  De fem regioner har udnyttet 94 % af de modtagne vaccinedoser.   Overblik og flere data her: https://t.co/aTkemLpfnM #COVID19dk https://t.co/7byUp1YOAo
#  -------
# Nå, godt så. Så blev jeg revaccineret og venter bare på at Bill Gates penge ruller ind på kontoen ......og chips!!!! GIV MIG CHIPS FOR HØVLEDE!!!!!!! øøøøh......eller.......ja.
#  -------
# @hsillesen I disse vaccine-trials ser man forskellen på teori og praksis folde sig ud i fuldt flor ... 🤗
#  -------
# @DKsundhed Kun SINDSYGE FOLK VIL TAGE EN IKKE FULD GODKENDT VACCINE DU IKKE KENDER LANGTIDS VIRKNINGEN AF ✅ SIKKE EN FLOK KLOVNE 🤡🤡🤡 https://t.co/VvOUq9jrvs
#  -------
# Vi har idag færdigvaccineret 4.808. I alt er vi oppe på 316.068 (5,40%)  Vi har påbegyndt vaccination for 4.804. I alt er vi oppe på 636.664 (10,9%)  For mere info tjek 👇 #COVID19dk #dkpol #sundpol #dkpol #dkmedier https://t.co/fXpbcXlyOu
#  -------
# @SteffenFrolund "En virksomhed beliggende i EU er ikke EU" Giv dem nu lige lidt tid til at blive helt færdige deres planer. Ingen længe er alt på EU's grund ejet af EU og til den tid er det jo de facto "EU's vacciner". Enkelte politikere får blot tager forskud på glæderne...
#  -------
# Færre smitteudbrud på plejehjem og færre indlæggelser, efter at vaccinationsindsatsen er sat i gang - https://t.co/ywqqRyEpgM https://t.co/NjAKTrCf7z
#  -------
# Nyt om vaccination mod COVID-19 på Ærø Region Syddanmark overtager driften af vaccinationsstedet i Rise Minihal. Læs mere  https://t.co/3xOjStZfse
#  -------
# #vaccination  Intet nyt under solen. Efter et lavpunkt lørdag 20/3 hvor kun 42 flere  blev stukket i @koebenhavner nåede vi i går  1.227. Heldigvis er kun ca. 10% af os over 65, så vi når nok snart 50+ mål 😍 @SophieHAndersen @SisseMarieWe @LykkePetri  #dkpol #dkmedier @tv2newsdk https://t.co/lsGzUwlcdW
#  -------
# @AFraViborg Andreas Søndergaard fra Viborg tager prisen for ham der er allermest Coronapresset i Danmark, hvis han kan lade sig forarge så meget at han må ryge til tastaturet over så lidt Bare tolig, Andreas. Der er nye vacciner på vej fra Belgien. Det er snart overstået det her.
#  -------
# Man må virkelig håbe, at de svageste er de stærkeste i denne tid. #COVID19 #vaccine @DiabetesDK #dkpol #sundpol  @Region_Midt   https://t.co/KghzXUfSfe
#  -------
# Er det gender biased? Antal af vaccinerede kvinder er langt højere end mændenes. Hvorfor? https://t.co/AB5Ozpo39R
#  -------
# @GianniRivera69 @mikaelmilhoj @MarcelFard Værdien af langmodig godkendelsesproces burde ses i forhold til alternativet som kan være længere nedlukning og/eller mindre at man tager mindre effektiv vaccine. Dem i Ungarn der får Sputnik sætter næppe pris på EMA grundighed
#  -------
# @DKsundhed Det danske vaccinatinosprogram er stort set ikke eksisterende  Igen under 10.000 vaccinationer i går  Vi kommer aldrig igennem hele befolkningen  #dkpol
#  -------
# @CameliaDewan @UWMartinsen @Elisabethis @GostaBroholmer Endelig en fordel ved at være mand i forhold til Covid-19 😊 Får jeg så din plads i vaccinekøen, Unni? 😁
#  -------
# Myndighed sadler om: Ændrer anbefaling om vaccineteknik efter meldinger om farlige bivirkninger https://t.co/MoKRet0vY2  Altså...
#  -------
# @jburmeister4321 Fuldstændig sikkert at modtage selve vaccinerne, det er vores sundhedspersonale som er så uprofessionelle at de ikke aner hvordan man skal vaccinere..... WTF ! Jamen så tror vi da på det... hold nu fast. De regner os for idioter. Propaganda maskinen kører på alle parametre.
#  -------
# @SSTSundhed Hej. Hvordan vil vacciner og sommerferie fungere? Mange er måske ikke i deres region, når de tilbydes vaccination pga ferie. På forhånd tak for svar og tak for jeres gode arbejde 😊
#  -------
# @itsMcDumbo @sillern Jeg slog den finske vaccine plan op i går for at se hvornår jeg kan regne med at besøge svigerfamilien. Hvis alt løber planmæssigt når det omtrent 100% til jul. (nogen vil vist stadig mangle dose2) https://t.co/DAjhovuFur https://t.co/NYJmU80R5M
#  -------
# @CBrunsholm @SaitoJanus @MaiVilladsen Man er ikke til fare for andre mennesker, hvis man ikke har taget vaccinen mod covid eller influenza. Det er blot dumt at påstå.
#  -------
# Putin får stik med coronavaccine tirsdag https://t.co/JktU00tyD5 via @berlingske
#  -------
# De deskriptive analyser fra @SSTSundhed indikerer, at vaccinerne allerede har haft en positiv effekt på vaccinegrupperne, dvs. plejehjemsbeboere, ældre og sundhedspersonalet.   Det er jo en super glædelig nyhed #covid19dk   https://t.co/s7suizHkIm https://t.co/OfSRSVgQt4
#  -------
# Vi får i @aeldresagen mange henvendelser fra medlemmer, der er angste for at få AZ-vaccinen og derfor er tæt på at vælge vaccinationen fra. Myndigheder bør have dette med i overvejelser & finde en løsning! Vi må undgå, at msk, der bør modtage tryg vaccination, ikke bliver det
#  -------
# Under én procent af vaccinerede har fået corona https://t.co/OPklRhwPOz https://t.co/pTL6opGbhi
#  -------
# År 2023:   De 37,6 % af danskerne, som er færdigvaccineret mod aggressiv hesteherpes, skal nu vaccineres påny, da den oprindelige vaccine har vist sig ikke at være virksom mod den bornholmske mutation af hesteherpes. https://t.co/4hBtdPVO2X
#  -------
# @MtnTeit @aeldresagen Jeg håber, at I fortæller dem, at det er en god og sikker vaccine 😊
#  -------
# Nu også studie i USA som siger Astra er en glimrende vaccine. Gas dog op under den herhjemme - som absolut minimum gøre den tilgængelig for de der ønsker den. Jeg står gerne forrest i køen
#  -------
# @mikaelmilhoj Min søster har fået første stik med AZ. Men hvis, man ikke fortsætter med den, så skal hun starte forfra med anden vaccine. Gad vide hvor mange, der står i den situation?
#  -------
# @mikaelmilhoj Er det torsdag man forventer Moderna vaccinerne kommer? Min morfar skal åbenbart have sådan en, og kan først bestille tid til den, når den er landet på dansk jord 🤨
#  -------
# @StellaHoedt @x01rose Bliver du influenzavaccineret?
#  -------
# @SaitoJanus @CBrunsholm @MaiVilladsen Michael Bang fra Hope projektet siger det meget godt: “Det næste halve år kommer debatten til at handle om frihed til morskab, eller frihed fra staten.” Som sagt er passet symbolsk. Du kan være smittet efter test, og smitte videre som vaccineret.   Det er starten på mere kontrol.
#  -------
# Nu kommer vaccinerne til de sociale botilbud22-03-2021 Onsdag den 24. marts bliver 'store vaccinedag' https://t.co/PLEQ2VQF0U
#  -------
# GODE, NYE TAL I KØLVANDET PÅ VACCINATIONSINDSATSEN💪 ✅Kun én plejehjemsbeboer COVID-19-smittet i uge 10  ✅Færre indlæggelser + fald i smitten blandt sundhedspersonale ✅+85-årige er pt. aldersgruppe m. lavest smitte.  Se mere hos @SSTSundhed https://t.co/mqMdtXLk6b #sundpol https://t.co/ik27KZWk22
#  -------
# @mikaelmilhoj Det er lige til at fælde en tåre over. Og om få måneder har vi vaccineret langt de fleste ældre, og det er næsten sommer. Hold nu kæft det er fedt.
#  -------
# @JulskovT @tv2newsdk Jeg har en medfødt kronisk sygdom på lungerne og er 55 år. Jeg er IKKE tilbudt vaccine endnu så stop dit negative svar. LANGT fra alle ældre og syge er vaccineret, følg med inden du ytre dig 😁
#  -------
# @itsMcDumbo @sillern Jeg bor i danmark. Min svigermor bor i Finland og passer meget på corona. Så hun vil nok ikke ses før vi alle er vaccineret. Jeg regner med at se dem tidligst til efteråret.
#  -------
# . Jeg forstår ikke dem der ikke vil have Astra Zenica vaccinen. Den er jo ikke farligere end selvmord. .
#  -------
# SSI anbefaler ny vaccineteknik efter sjældne blodpropper https://t.co/cZKxihWJjM https://t.co/n664Me7QAa
#  -------
# @tv2newsdk Ja forlang 200- 300 kr for en vaccine akkurat som så mange andre vacciner koster. Vil også bidrage til danskernes slunkne kassebeholdning. Og lad det så være frit om hvilken vaccine man vil have jeg skal IKKE have AC og spille rusisk roulette med mit liv dæleme NEJ
#  -------
# @tv2newsdk Stop nu det har jo ikke noget med teknikken st gøre, er det tilfældet var der jo samme problem med de to andre vacciner. STOP nu med at fylde os med løgn men åbenbart ok vi tager et liv i ny og næ med AC det er sku skræmmende.
#  -------
# @jburmeister4321 @MetteKjaer7 Ikke sjovt at have gættet rigtigt. Skrev f dage siden at efter blodpropperne kom der en ny undskyldning, som kunne være, at vaccinen blev givet forkert. Næste gang : "Alle var i forvejen dødeligt syge, men de el fam/venner vidste det ikke..." Fat det👇(fra januar) https://t.co/prSEjTobJL
#  -------
# #covid19dk Vaccinering i Danmark. 952.732 doser er brugt.  10,9 procent af befolkningen (636.664 personer) har fået første dosis, og 5,4 procent af befolkningen (316.068 personer) har også fået 2. dosis og er fuldt vaccinerede. 93,9 % af de modtagne doser er brugt. https://t.co/jmcmDY91Ae
#  -------
# Uden HIV-forskning ingen COVID-19 vaccine💉  Havde det ikke været for blindgyderne i forskningen omkring i HIV-vaccine, havde vi ikke haft COVID-19 vacciner i dag. Det skriver sundhedsøkonom Jeffrey Harris fra MIT i dette nye working paper #COVID19dk #sundpol #dkøko https://t.co/Z6zyVKcu6l
#  -------
# @MtnTeit @aeldresagen Det kan I selvfølgelig ikke, men hvis ellers AZN bliver nogenlunde frikendt også i den danske/nordiske undersøgelse, så har vi jo alle et ansvar for at dele det budskab. Jeg er dog enig i, at myndighederne står med et stort problem i fht fordeling af vaccinetyper fremover...
#  -------
# @JonasHerby når prositivprocenten falder fra 1,6% til 0,3% pga nye regler fra WHO i januar så falder antallet af positive fra hospitalsindlæggelser også til ca 1/5. pga. vacciner må COVID dødsraten være steget voldsomt?
#  -------
# Først tøvede han, men nu vil Putin lade sig vaccinere i morgen https://t.co/AkibjXOqD4
#  -------
# @CameliaDewan @UWMartinsen @Elisabethis @GostaBroholmer Fandt det. Lyder meget beskedent ifht., at UK har vaccineret virkelig mange. https://t.co/bt2ijJsEHq
#  -------
# 🆕 0,6%. Vaccinerne virker. Vi kan se slutningen på pandemien.  https://t.co/ReyK5aUt2a
#  -------
# @Ullegaard @venstredk Det havde været bedre, om oplægget var mere præget af fakta end ideologi, men Venstre har jo aldrig støttet begrænsning af den omtalte virus.   Et coronapas burde slet ikke indgå, og ønsket om, alle over 50 vaccineres først, passer godt med alderen på beslutningstagerne.
#  -------
# @GerEllen @CameliaDewan @Elisabethis @GostaBroholmer Tak for link! Og ja, det er ikke mange tilfælde når man ser på hvor mange der har modtaget vaccinen.
#  -------
# @NDybmose Hej Natasja. Vi laver disse daglige opdateringer, da vi ofte får spørgsmål om status på vaccinationer i Danmark.
#  -------
# @kristianskriver Ved vi egentlig noget om hvor mange midlertidige corona jobs der er, og om det spiller ind? Evt. om de forsvinder eller kan overgå til andre funktioner.   Altså fx. PCR-podere, quick-test podere, diverse support funktioner, smitteopsporer, vaccineudrulnings ansvarlige osv?
#  -------
# Det er sundhed - inklusive vaccination - tæt på dig!
#  -------
# Sundhedsstyrelsen har ændret i vaccinationsprogrammet, så målgrupperne 5, 6, 10 og 11 afrundes, og man fremover primært inviteres til vaccination efter alder. De ældste vaccineres først.  #sundhed #dkpol  https://t.co/ltUfz0NmtE https://t.co/dXt5yEPhkH
#  -------
# @SaitoJanus @itsMcDumbo @MaiVilladsen Virker deres vacciner da ikke? Det har og vil altid være farligt at være svagelig, kronisk syg og ældre. Der er 999+ andre risici udover corona.  Har du altid været så hensynsfuld og ladet dig vaccinere, teste eller isolere i hele den årlige influenzasæson?
#  -------
# #VaccinesWork  @RegionH har tilsyneladende 28.819 doser @AstraZeneca på frys... #dkpol #dkmedier @tv2newsdk @DR1TV  @dr2deadline https://t.co/5AdgldH1Vo
#  -------
# @peter2990 @mortensode Korrekt - epidemier er relative vækstrater, så niveauet betyder ganske meget. Og helt afgørende for "væksten". det vil man umiddelbart kunne overbevise sig om ved at opskrive tilstandsligningen for en (evt. modificeret) SIR-model (evt. indeholdende vaccination) 😉
#  -------
# @ClarkJamesYNWA Coronaen har helt sikkert gjort, at jeg glæder så meget til EM. Jeg vil bare gerne have EM, havefest, vacciner og sommer.
#  -------
# EU-vacciner: vi må vist bare se, hvad der sker på torsdag  👇 #eudk
#  -------
# ...
#  -------
# @SorenPape Super..SÅ i har nu valgt at acceptere "UNDERMENNESKER". En gruppe som INTET kan/må, hvis de ikke lægger sig under for PCR test, eller vaccine !. Jamen hip hip hurra for jer.. hvor er i dygtige !. Og øh...eftersom pas er i forbindelse med genåbning, hvornår FJERNES det så igen !?
#  -------
# Genåbningsplan: slut med stort set alle restriktioner, når alle over 50 har fået tilbudt vaccination mod corona #COVID19DK #dkpol
#  -------
# @pelledragsted @MaiVilladsen Især når man tager i betragtning, at man nu dropper gruppe 10. Så en masse sårbare unge mennesker, skal befinde sig i et samfund med udbredt smitte uden at blive tilbudt vaccination. Endnu gang for dårligt.
#  -------
# Ifølge vaccinationsplanen burde alle over 50 være vaccineret i begyndelsen af juni. Så er EM vel reddet? https://t.co/ZmIUEQYKU2
#  -------
# @Berry1952K Mere eller mindre alle restriktioner er væk når personer over 50 år har fået tilbudt vaccine.
#  -------
# Covid kan føles som “konservativ Anno 2021” Man skal passe på ikke at blive smittet med egoisme, holde afstand, passe på hvem man taler med, man kan dø af det, leve et ensomt kort liv. Man skal vaccineres. kh @alternativet_  🧤🌱☘️🍀💚 @folketinget @dr2deadline #dkpol @politikdr
#  -------
# @Mlundby Det kommer vel an på levering af vacciner?
#  -------
# Som jeg har prøvet at sige tidligere, så har der været for stort fokus på, hvornår sidste person ville få sidste stik. Pandemien er en helt anden størrelse, når de +50-årige er vaccineret. Derfor bliver det godt med flere vaccinedoser, så vi kan komme i mål 🤩
#  -------
# @MartinFlink @uffe1974 @w1lhelms @gergenzola Så kan du få min vaccine, så tager jeg lottokuponen.
#  -------
# WHO: Ujævn fordeling af vacciner bliver mere og mere grotesk https://t.co/AJdDhcsR6T https://t.co/Of3WlAROeQ
#  -------
# Jeg er hverken blevet testet eller vaccineret, og sådan forbliver det, så længe jeg kan gøre modstand.   Men jeg ser frem til at staten skaber et nyt lukrativt marked - nemlig at tilbyde ydelser til folk uden coronapas, også kan staten ellers vinke farvel til indtægterne herfra.
#  -------
# @FrejElbaek Indtil videre har “Coronapas” været = enten vaccine eller negativ test eller antistoffer - i samme ordning, som giver samme adgang
#  -------
# nej men,, det altså lidt vildt at tænke på at man nok har fået tilbudt en vaccine om to måneder
#  -------
# @jyllandsposten “Den 6. april er det igen muligt at gå til eksempelvis frisør eller massør, men det kræver en negativ coronatest, og at man er vaccineret eller kan påvise, at man tidligere har været smittet med coronavirus.”  Skal man stadig have en test, selvom man er vaccineret?
#  -------
# Hvis du er blevet vaccineret eller har været syg af corona... så, ikke mig... havde ellers helt strategisk bestilt tid hos min frisør efter påske. Øv, I was out-smarted. https://t.co/sUhrbb0Eds
#  -------
# Coronapasset indføres i Danmark. Det betyder at danskerne skal tvinges til vaccination, med en vaccine ingen kender langtidsvirkningen af, for at kunne blive klippet og spise på restaurant.
#  -------
# Om godt to uger åbner liberale erhverv som frisører, hvis man er vaccineret eller har negativ coronatest. https://t.co/NGEMv8MCmA
#  -------
# EU har været ”masters of their own downfall”.  Briterne mener ikke, at de skal straffes for at have gjort sig fri af EU, siger @illeborg_jakob om vaccinestriden mellem de to parter. https://t.co/D4fOOYkoIE
#  -------
# Efter Brexit-forhandlingerne var håbet, at man skulle i gang med at være pragmatiske og venskabelige. Det er bestemt ikke det, vi har set med vaccinestriden mellem EU og UK, som potentielt har virkelig vidtrækkende konsekvenser, siger @louisewith fra @borsendk https://t.co/3hTogpEvv5
#  -------
# Fedt jeg kan komme til frisøren når jeg er blevet vaccineret!..  ...om 5 måneder.
#  -------
# Alle restriktioner ophæves når alle over 50 år har fået tilbud corona vaccination 🙏💐👍❤
#  -------
# Nattelivet - herunder alkoholservering efter kl. 22 - vil tidligst blive genåbnet efter alle over 50 er vaccineret. #dkpol #dkmedier #covid19dk
#  -------
# @Statsmin Jeg er glad for en forsigtig men dog markant åbning efterhånden som vaccination bliver udbredt. Og jeg er glad for bred aftale - det er ikke tid til partipolitiske sololøb, selv om et enkelt parti valgte den vej. Jeg er glad for Danmark foreløbig er kommet et skridt frem. #dkpol
#  -------
# siger du til mig at bare fordi vi som unge bliver vaccineret til sidst så får vi også som sidste coronapas hvilket betyder vi som de sidste kan gøre ting????? bruh
#  -------
# Nu er genåbningsplanen her: Danmark åbner når alle over 50 år er vaccineret https://t.co/7kJSNf8jL3
#  -------
# Virkelig godt for DK med bred genåbningsaftale, hvor #dkpol sammen tager ansvar og sikrer vished i samfundet, som #dkbiz har efterspurgt. Vi er meget tilfredse med enigheden om fuld genåbning, når alle +50 år er vaccineret, og at coronapas tages i brug for at kunne åbne tidligere
#  -------
# Om jeg skal vaccineres, kommer godt nok an på om der er styr på vaccinerne, og det kommer Mette ikke til at vurdere om jeg syntes der er 🤷‍♂️🤷‍♂️#dkpol #dkmedier  Aftale: Danmark åbner når alle over 50 år er vaccineret https://t.co/nbMYjPUpt0
#  -------
# Kan forestille mig at smittefester bliver en ting, hvis man bla. kan få coronapas ved antistoffer. Hvis man er bagerst i vaccinekøen og passet kræves for at deltage i samfundet, ville jeg da selv overveje det for ikke at skulle testes konstant. Virker ikke gennemtænkt. #dkpol
#  -------
# @hiyahypen hmm åbenbart noget med at man kun kan gå i liberale erhverv og restauranter med coronapas? hvilket jo er nederen for de unge som først får vaccine til sidst.... men er ikke helt sikker ahahh
#  -------
# @data02 Jeg er ikke uenig, men de har foretrukket at tilgodese flere parter på en gang. Vi må tage hvad vi kan få indtil alle over 50 er vaccineret
#  -------
# "Når vaccinationen af de ældste og sårbare borgere samt borgere over 50 år, der ønsker det, er gennemført, er det udgangspunktet, at skoler og uddannelser kan genåbne fuldt ud". Hvorfor ikke før? De var fuldt genåbnet i december. Hvorfor skal man nu vente til sommer? #dkpol
#  -------
# @MereteKonnerup R=1,1 kan håndteres.... en fordobling vil tage lidt over en måned og kan bremses med vaccination.  Så nok ingen grund til panik endnu.
#  -------
# Det føles som en kæmpe fuckfinger til de liberale erhverv og restauranter. Nu kommer de til at miste flere kunder og de indfører indirekte tvang til vaccination og tests.
#  -------
# @Skuffet66 @SorenPape Det skal drøftes månedligt, det har solnedgangsklausul og det vil fjernes når alle +50 år er tilbudt og påbegyndt en vaccine
#  -------
# @VilasHJensen Så må vi jo bare få AZ vaccinen tilbage i en fart ;)
#  -------
# @dinabpigen Ok? Jeg så kun, at det var vaccineret, eller bevis på at man havde været syg...
#  -------
# @PernilleBlid @viggo1986 @PiaOlsen Vaccinepas vil være gyldigt hvis man er fuldt vaccineret, negativ test som er max 72 timer gammel eller kan tidligere har været påvist smittet.
#  -------
# @PiaOlsen Ja i må da være SÅ STOLTE...at sætte FED TYK STREG under at man nu er undermennesker i DK, hvis man ikke vil frasige sig sin grundlovssikret ret, og underlægge sig pcr test eller vaccine !!. FØJ FOR SATAN. Det værste er at du er for dum og lalleglad til at vide hvor sygt det er !
#  -------
# @KHegaard God plan! Lad os håbe vaccinerne bliver tilgængelig for alle os andre under 50 og som endnu ikke er blevet den tilbudt, så vi *også* kan deltage i festlighederne.
#  -------
# 6 April: 5-8 klasse/ungdoms og voksenuddannelser kommer tilbage i skole på ½ tid  Liberale erhverv genåbner  Indførelse Coronapas, så negativ test/vaccinering giver adgang til for eksempel klipning  Yderligere åbner med 14 dages mellemrum  Alle undtagen NB bag forliget #COVID19dk
#  -------
# @MVesterj Og nu er der færre indlagte, og flere personer bliver vaccineret. Synes ikke helt, det giver mening
#  -------
# @tv2newsdk Hvis det er teknikken, det er galt med, hvorfor er det så ikke samme problem med de øvrige vacciner? 🤔 Jeg undrer mig bare...
#  -------
# Allerede på side et i den nye genåbningsaftale er der et problem. Folk der ikke er “digitale” skal have tilsendt “coronapas” med posten. Men hvordan skal man kunne få et prøvesvar, der ikke er 72 timer gammelt, sendt med posten?  Vaccinebevis går an.   #digidk @aeldresagen
#  -------
# @fnehfnehOP har været på p piller i fire år så mon ikk ogs min krop kan klare en vaccine uden en blodprop HDBS
#  -------
# @RasmusKjeldahl Det står i aftalen - når alle over 50 år er tilbudt vaccine @RasmusKjeldahl
#  -------
# Så langt - så godt. Nu ved vi så det. Flere tilbage på deres udd.inst. efter påske 🐣 - må vaccinationer, foråret og vores alle sammens betænksomme adfærd - betyde, at vi får alle med 100 pct. #uddpol #dkpol https://t.co/fpU3RsDjSu
#  -------
# @mrskou @Ern_st Tja, så må de skrue ned for det igen, hvis det ikke fungerer, derfor det åbner op i etaper med mulighed for at hive i bremsen, hvis tallene udvikler sig forkert. Med forår på vej og flere vaccinationer, så er jeg positiv, det så man jo sidste år, og det var endda uden vacciner 😊
#  -------
# @AKCramon Du ER godt klar over at selv om du ikke er vaccineret, så virker coronapasset også med negative tests, ikke?   Dit tweet virker ikke gennemtænkt.
#  -------
# @viggo1986 @PiaOlsen Det var da helt vilde sammenligninger. A/B borgere hvordan? Tests er gratis og vil du ikke vaccineres kan du bruge tests. Og hvordan kan du overhovedet finde på at sammenligne med jødestjernen og jødeforfølgelserne...!
#  -------
# 35.000 af de mest sårbare ældre og handicappede har ikke responderet på indkaldelse til vaccination.Jeg håber at myndighederne går på undersøgelse i årsagen og søge alternative kontaktveje. E-boks og tidsbestillingssystem kan være en barriere for mange.#dkhandicap #dkpol #sundpol https://t.co/AE3VYSJaxE
#  -------
# Slaglinjen: "Danmark åbner, når alle over 50 år er vaccineret" fylder i denne genåbningsplan. Men det gælder ikke alle i #dkbiz
#  -------
# @JesperSimo Nattelivet er slet ikke nævnt, men man må vel antage, at det så er når alle er vaccineret. Dog er jeg dybt bekymret for EM i Parken. Lyder til det glipper
#  -------
# @edtwodth Det fremgår af aftalen, at der vil være mulighed for at fremvise bevis på vaccination og negativ coronatest ubeaukratisk uden digitale hjælpemidler.
#  -------
# Planer er godt, men vaccinerne skal udrulles. Måske den bedste vej til genåbning ville være at lade København lære af Læsø hvordan man får borgerne vaccineret? #Covid19dk #dkpol https://t.co/uWQnQIRHMB
#  -------
# Bemærk: Det er når alle 50+, der ønsker vaccine, har fået FØRSTE stik, at Epidemikommissionen skal vurdere om nattelivet - eller dele heraf - kan genåbnes. Jf. vaccinationskalenderen fra 17. marts, så er det ved udgangen af U19. Altså cirka d. 17. maj. #dkpol #dkmedier #covid19dk
#  -------
# 50 % genåbning i folkeskolen er vigtigt - men at vente med fuld genåbning i skolerne til alle over 50 har fået tilbudt vaccine bringer os nærmest frem til sommerferien. Meget andet åbner inden - kan det kaldes børnene først? #dkmedier #dkpol
#  -------
# Vigtigt for #dkbiz med Folketingets aftale om fuld genåbning, når alle over 50 år er vaccineret, siger @LarsSandahlS #dkpol #covid19dk  https://t.co/jYb3782E6z
#  -------
# @Kristianthdahl Fint med jer. Hvad så med dem, som ikke har et digital medier. Hvad skal de så vise, for at bevise at de er vaccineret #dkpol #dkmedier @statsmindk @DKsundhed @SSTSundhed @venstredk @JakobEllemann
#  -------
# @SteffenFrolund Nogen skal have skylder for at vi ikke kan følge med i at få skabt “flokimmunitet” I befolkningen.. #AstraZeneca #vaccination
#  -------
# @dinabpigen ikke nødvendigvis. For når alle 50+, der ønsker det, har fået første stik, så skal epidemikommissionen vurdere fx genåbning af nattelivet - eller dele heraf. Det er jf. den seneste vaccinationskalender d. 17. maj
#  -------
# Jeg har svært ved at udtrykke min skuffelse over at stå sidst i den uendelige kø til vaccinen, men så er det jo skønt, at jeg med det nye vaccinepas i hånden kan vælge at lade mig smitte med Covid-19 for på den måde at få lov at blive klippet og komme i biografen igen.
#  -------
# @juhl_svendsen @4dorthe Jeg nøjes med at skimme den, men der sker lidt hver 14 dag og https://t.co/5AfGh6nzSP app skal i første omgang bruges som coronapas, både for at gå til frisør eller test senest 72 timer før, eller ha haft corona, eller været vaccineret, alle vaccineret 1.gang midt maj åbnes helt.
#  -------
# Den 1. juli kan jeg måske blive klippet, tage på restaurant eller diskutere politik over en fadøl - såfremt vaccinationsplanen ikke bliver ændret igen & igen & ... #dkpol
#  -------
# @nkslarsen @linigerDR Tværtom. Med et fungerende vaccinepas, så er det "kun" danskere mellem 25 og 40, der ikke er blevet vaccineret ved EMs start.
#  -------
# @VilasHJensen Jeg forstår godt din tvivl. Men mit bedste bud er hvertfald de er under "nattelivet" pga. alkoholsalget. Og det åbner jo først efter alle over 50 år er vaccineret.
#  -------
# Godt med en god plan. Krydser fingre for, at smitten holder sig nogenlunde i ro og at vaccineplanen holder #dkpol #COVID19dk #vaccinedk
#  -------
# @FrejElbaek Jeg kan godt vente til flertallet ER vaccinerede, så kan du også komme til SL-kamp og se AGF få tæsk
#  -------
# Danmark åbner når alle over 50 år er vaccineret https://t.co/k28RjdkDtd
#  -------
# @KHegaard Jeg er ham der ikke er vaccineret og aldrig teste som ødelægger den gode stemning i salonen  , vælter jeres klapbord så der øl over alt .  Og skyggen der rører hele buffeten med hænderne , og er pist væk igen .   Er ekspert i at lave scener folk aldrig glemmer 👍
#  -------
# @helleib Fair enough - hvis altså vaccinen var rullet ud😊 Men min mor venter stadig på sin vaccine 😥🤷‍♂️
#  -------
# @SimoniMq Ved du hvad det betyder ? Er det tilbud  om første stik modtaget i Eboks - eller færdigvaccineret ? Gør stor forskel
#  -------
# @karmel80 Skyldes særlige geografiske forhold som gør at man har giver doser på en gang (en del af de vacciner vi har nu er ikke så nemme at transportere  lang tid). Dermed ikke læring til København men løsning af særlige geografiske udfordringer...
#  -------
# @PiaOlsen Ja - men når jeg læser aftalen og tjekker med vaccineplanen ser det ikke ud til at børnene er fuldt tilbage før de alligevel skal på sommerferie - forklar mig gerne hvor jeg tager fejl...
#  -------
# @SimoniMq Faktisk står der når vaccinationen er gennemført - dvs engang i løbet af juni
#  -------
# Danmark åbner når alle over 50 år er vaccineret https://t.co/EMSdoZ38wk https://t.co/RourAbE5WV
#  -------
# @MaiVilladsen sindssygt skuffende resultat - men jeg kan næsten regne ud at hvis min familie og jeg vil leve et almindeligt liv på lige fod med resten af danskerne, men ikke ønsker at modtage den eksperimentelle vaccine, skal vi alle hurtigst muligt finde en der kan smitte os med covid19....
#  -------
# @RasmusKjeldahl Og? Børn skal ikke være vaccineret?
#  -------
# Ny aftale om genåbning: Danmark skal være næsten åbent, når alle over 50 år har fået tilbudt vaccine https://t.co/DYkKrlEZxy
#  -------
# @politiken Fedt med vaccinepas, ellers kunne landet først åbne sikkert op sidst i juli🤗
#  -------
# Yes!!! Får første skud vaccine tirsdag 😊
#  -------
# @edtwodth @Kristianthdahl Nu er englændere også flere end vi danskere, men ja - vaccinationen kunne være bedre. Det har bare ikke noget at gøre med denne genåbningsaftale.
#  -------
# @ThorupLange @Kristianthdahl Uanset om man retter det til ift indbyggertal så er der stadig stor forskel  Det har da netop alt at gøre med genåbningsplan: jo hurtige over 50 bliver vaccineret, jo hurtigere åbner Danmark
#  -------
# @jyllandsposten Køb hos nogle af afrikanske lande som sælger deres partier pga de ved de ikke virker og at døden følger vaccinerne 😉👍🏽  Win-win
#  -------
# Vi har brug for et Frihedsparti i Danmark efter de blå partier har svigtet. Pandemien er slut og alligevel ævler de om restriktioner, test og coronapas. Risikogrupper udgør under 2% og 11% er allerede vaccineret #dkmedier #dkpol. Det er galimatias hvad der sker i Danmark.
#  -------

# %%
import spacy
import string
from string import digits
import re
sp = spacy.load('da_core_news_lg')

file = open("../hope-keyword-templates/src/stop_words.txt","r+")
stop_words = file.read().split()

# Lemmatize stop words
stops = " ".join(stop_words)
stops = sp(stops)
my_stop_words = [t.lemma_ for t in stops]
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

def lemmas(row):
    tweet = row["mentioneless_text"].lower()
    tweet = remove_emoji(tweet)
    tweet = re.sub(r'@(\S*)\w', '', tweet) #mentions
    tweet = re.sub(r'#\S*\w', '', tweet) # hashtags
    # Remove URLs
    url_pattern = re.compile(
        r'(https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|www\.[a-zA-Z0-9][a-zA-Z0-9-]+[a-zA-Z0-9]\.[^\s]{2,}|https?:\/\/(?:www\.|(?!www))[a-zA-Z0-9]+\.[^\s]{2,}|www\.[a-zA-Z0-9]+\.[^\s]{2,})')
    tweet = re.sub(url_pattern, '', tweet)
    
    tweet = tweet.translate(str.maketrans('', '', string.punctuation))
    #tweet = tweet.translate(str.maketrans('', '', digits))
    tweet = tweet.replace('”', '')
    tweet = tweet.replace('“', '')
    
    sentence = sp(tweet)
    lemmas = []
    for word in sentence:
        lemmas.append(word.lemma_)
    res = [x for x in lemmas if x not in my_stop_words]
    hmm = ['   ','  ',' ','','♂','','❤','','🤷']
    res = [x for x in res if x not in hmm]
    return res

def join_tokens(row):
    res = " ".join(row["tokens_list"])
    return res

# %%
sub = winter_df[winter_df["date"] == "2021-03-22"].reset_index()

# %%
sub["tokens_list"] = sub.apply(lambda row: lemmas(row), axis = 1)
sub["tokens_string"] = sub.apply(lambda row: join_tokens(row), axis = 1)
#texts = freq_df["tokens_string"]
word_freq = sub.tokens_string.str.split(expand=True).stack().value_counts()
word_freq = word_freq.to_frame().reset_index().rename(columns={"index": "word", 0: "Frequency"})

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import pyplot_themes as themes

word_freq = word_freq[~word_freq["word"].isin(stop_words)]
df0 = word_freq.nlargest(30, columns=['Frequency'])
nr_hash = len(df0["word"].unique())

matplotlib.rc('ytick', labelsize=30)
matplotlib.rc('xtick', labelsize=30)

themes.theme_minimal(grid=False, ticks=False, fontsize=18)
a4_dims = (25,15) #(11.7, 8.27)

fig, (ax) = plt.subplots(1,1, figsize=a4_dims)

themes.theme_minimal(grid=False, ticks=False, fontsize=18)
palette = sns.color_palette("Blues_r", nr_hash)

ax = sns.barplot(y="word", x="Frequency", palette = palette, data = df0)

ax.set(xlabel="Count", ylabel = "Hashtag")
ax.xaxis.get_label().set_fontsize(25)
ax.yaxis.get_label().set_fontsize(25)
ax.axes.set_title("Most frequent words",fontsize=50)

plt.xticks(fontsize=40)
plt.yticks(fontsize=25)

ax.set(xlabel="", ylabel = "")
ax.xaxis.get_label().set_fontsize(100)
ax.yaxis.get_label().set_fontsize(40)

#plot_name = "fig/word_frequency.png"
#fig.savefig(plot_name)

# %%
sub = winter_df[winter_df["date"] == "2021-03-23"].reset_index()
sub["tokens_list"] = sub.apply(lambda row: lemmas(row), axis = 1)
sub["tokens_string"] = sub.apply(lambda row: join_tokens(row), axis = 1)
#texts = freq_df["tokens_string"]
word_freq = sub.tokens_string.str.split(expand=True).stack().value_counts()
word_freq = word_freq.to_frame().reset_index().rename(columns={"index": "word", 0: "Frequency"})


word_freq = word_freq[~word_freq["word"].isin(stop_words)]
df0 = word_freq.nlargest(30, columns=['Frequency'])
nr_hash = len(df0["word"].unique())

matplotlib.rc('ytick', labelsize=30)
matplotlib.rc('xtick', labelsize=30)

themes.theme_minimal(grid=False, ticks=False, fontsize=18)
a4_dims = (25,15) #(11.7, 8.27)

fig, (ax) = plt.subplots(1,1, figsize=a4_dims)

themes.theme_minimal(grid=False, ticks=False, fontsize=18)
palette = sns.color_palette("Blues_r", nr_hash)

ax = sns.barplot(y="word", x="Frequency", palette = palette, data = df0)

ax.set(xlabel="Count", ylabel = "Hashtag")
ax.xaxis.get_label().set_fontsize(25)
ax.yaxis.get_label().set_fontsize(25)
ax.axes.set_title("Most frequent words",fontsize=50)

plt.xticks(fontsize=40)
plt.yticks(fontsize=25)

ax.set(xlabel="", ylabel = "")
ax.xaxis.get_label().set_fontsize(100)
ax.yaxis.get_label().set_fontsize(40)

# %%
sub = winter_df[winter_df["date"] == "2021-01-13"].reset_index()
sub["tokens_list"] = sub.apply(lambda row: lemmas(row), axis = 1)
sub["tokens_string"] = sub.apply(lambda row: join_tokens(row), axis = 1)
#texts = freq_df["tokens_string"]
word_freq = sub.tokens_string.str.split(expand=True).stack().value_counts()
word_freq = word_freq.to_frame().reset_index().rename(columns={"index": "word", 0: "Frequency"})


word_freq = word_freq[~word_freq["word"].isin(stop_words)]
df0 = word_freq.nlargest(30, columns=['Frequency'])
nr_hash = len(df0["word"].unique())

matplotlib.rc('ytick', labelsize=30)
matplotlib.rc('xtick', labelsize=30)

themes.theme_minimal(grid=False, ticks=False, fontsize=18)
a4_dims = (25,15) #(11.7, 8.27)

fig, (ax) = plt.subplots(1,1, figsize=a4_dims)

themes.theme_minimal(grid=False, ticks=False, fontsize=18)
palette = sns.color_palette("Blues_r", nr_hash)

ax = sns.barplot(y="word", x="Frequency", palette = palette, data = df0)

ax.set(xlabel="Count", ylabel = "Hashtag")
ax.xaxis.get_label().set_fontsize(25)
ax.yaxis.get_label().set_fontsize(25)
ax.axes.set_title("Most frequent words",fontsize=50)

plt.xticks(fontsize=40)
plt.yticks(fontsize=25)

ax.set(xlabel="", ylabel = "")
ax.xaxis.get_label().set_fontsize(100)
ax.yaxis.get_label().set_fontsize(40)
