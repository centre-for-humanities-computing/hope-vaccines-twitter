# %% [markdown]
# # Explore vaccines data

# %%
import pandas as pd
import numpy as np
from icecream import ic
import datetime

import seaborn as sns; sns.set()
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pyplot_themes as themes
import datetime as dt

# %%
df = pd.read_csv("../hope-keyword-templates/vaccin_smoothed.csv")
ic(len(df))
df = df.drop_duplicates()
ic(len(df))
df = df.sort_values("date")
df.head()
# Out:
# ic| len(df): 82905
# ic| len(df): 82905
#      index           created_at            id  \
# 0    33766  2021-01-01 00:05:19  1.344797e+18
# 427  34206  2021-01-01 18:22:06  1.345073e+18
# 428  34207  2021-01-01 18:22:21  1.345073e+18
# 429  34208  2021-01-01 18:22:42  1.345073e+18
# 430  34209  2021-01-01 18:22:59  1.345073e+18
#
#                                                   text search_keyword  \
# 0    Meget rørt her i Villa villakulla mormor’s Val...     ['vaccin']
# 427  @DRNyheder Dronningen tilhører en risikogruppe...     ['vaccin']
# 428  @DRNyheder Jeg havde forstået at de to kategor...     ['vaccin']
# 429  @M_M_Pedersen @Kristian_Jensen JEG mener, her ...     ['vaccin']
# 430  Hvis kongehuset skulle have nogen som helst fo...     ['vaccin']
#
#            date                                  mentioneless_text  \
# 0    2021-01-01  Meget rørt her i Villa villakulla mormor’s Val...
# 427  2021-01-01   Dronningen tilhører en risikogruppe. Statsmin...
# 428  2021-01-01   Jeg havde forstået at de to kategorier som ma...
# 429  2021-01-01    JEG mener, her på min private Twitter, det e...
# 430  2021-01-01  Hvis kongehuset skulle have nogen som helst fo...
#
#                                                 text50  dupe50    neg  ...  \
# 0    Meget rørt her i Villa villakulla mormor’s Val...   False  0.000  ...
# 427   Dronningen tilhører en risikogruppe. Statsmin...   False  0.087  ...
# 428   Jeg havde forstået at de to kategorier som ma...   False  0.000  ...
# 429    JEG mener, her på min private Twitter, det e...   False  0.045  ...
# 430  Hvis kongehuset skulle have nogen som helst fo...   False  0.000  ...
#
#             day   entropy  normalized_entropy  centered_entropy  \
# 0    2021-01-01  5.077014            0.494716          0.032951
# 427  2021-01-01  5.077014            0.494716          0.032951
# 428  2021-01-01  5.077014            0.494716          0.032951
# 429  2021-01-01  5.077014            0.494716          0.032951
# 430  2021-01-01  5.077014            0.494716          0.032951
#
#      s2000_entropy s2000_compound  s2000_nr_of_tweets  s5000_entropy  \
# 0         5.083264       0.044157          643.142835       5.120173
# 427       5.087294       0.044800          654.091990       5.124487
# 428       5.087307       0.044802          654.130980       5.124497
# 429       5.087320       0.044805          654.170044       5.124507
# 430       5.087333       0.044807          654.209182       5.124517
#
#      s5000_compound  s5000_nr_of_tweets
# 0          0.052946          757.901141
# 427        0.054191          772.909533
# 428        0.054194          772.945486
# 429        0.054197          772.981442
# 430        0.054200          773.017401
#
# [5 rows x 25 columns]

# %%
df["date"] = pd.to_datetime(df["created_at"], utc=True).dt.strftime('%Y-%m-%d')
df["date"] = pd.to_datetime(df["date"])

start_date = "2021-01-01" #datetime.date(2021, 1, 1)
mask2021 = (df['date'] >= start_date)
mask2020 = (df['date'] < start_date)
mask2020winter = (df['date'] < "2021-01-01") & (df['date'] >= "2020-11-01")

ic(len(df.loc[mask2021]))
ic(len(df.loc[mask2020winter]))
ic(len(df.loc[mask2020]))
# Out:
# ic| len(df.loc[mask2021]): 82905
# ic| len(df.loc[mask2020winter]): 0
# ic| len(df.loc[mask2020]): 0
# 0

# %% [markdown]
# ## Tweet frequency over time

# %%
print(df.loc[mask2021].nr_of_tweets.describe())
print(df.loc[mask2020winter].nr_of_tweets.describe())
# Out:
# count    82905.000000
# mean       687.760364
# std        443.347478
# min        204.000000
# 25%        421.000000
# 50%        573.000000
# 75%        777.000000
# max       2590.000000
# Name: nr_of_tweets, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: nr_of_tweets, dtype: float64

# %%
df.nr_of_tweets.describe()
# Out:
# count    82905.000000
# mean       687.760364
# std        443.347478
# min        204.000000
# 25%        421.000000
# 50%        573.000000
# 75%        777.000000
# max       2590.000000
# Name: nr_of_tweets, dtype: float64

# %%
df["date"] = pd.to_datetime(df["date"])
df['date_ordinal'] = pd.to_datetime(df['date']).apply(lambda date: date.toordinal())

# %%
def set_base_plot_settings(fontsize, if_palette):
    matplotlib.rc('ytick', labelsize=fontsize)
    matplotlib.rc('xtick', labelsize=fontsize)
    themes.theme_minimal(grid=False, ticks=False, fontsize=fontsize)
    a4_dims = (25,15)
    
    if if_palette:
        #          0 black      1 orange  2 L blue   3 green    4 L orange  5 D blue  6 D orange 7 purple
        palette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]
    else:
        palette = 0
    
    fig, (ax1) = plt.subplots(1,1, figsize=a4_dims)
    sns.set(font_scale = 2)

    return fig, ax1, palette

def set_late_plot_settings(if_dates):
    ax1.set(xlabel="", ylabel = "")
    ax1.xaxis.get_label().set_fontsize(40)
    ax1.yaxis.get_label().set_fontsize(40)

    ax1.grid(color='darkgrey', linestyle='-', linewidth=0.5, which= "both")
    if if_dates:
        # Define the date format
        ax1.xaxis_date()
        date_form = mdates.DateFormatter("%d-%b")
        ax1.xaxis.set_major_formatter(date_form)

    ax1.set(ylim=(0, None))
    
    #ax1.set_yticklabels(ax1.get_yticks(), size = 35)

    #fig.suptitle("Mentions of 'vaccin*'. 2020 - 2021", size = "40")
    return fig, ax1

def set_late_barplot_settings():
    ax1.set(xlabel="", ylabel = "")
    ax1.xaxis.get_label().set_fontsize(40)
    ax1.yaxis.get_label().set_fontsize(40)
        
    #ax1.set_yticklabels(ax1.get_yticks(), size = 35)

    #fig.suptitle("Mentions of 'vaccin*'. 2020 - 2021", size = "40")
    return fig, ax1

# %%
fig, ax1, palette = set_base_plot_settings(fontsize=30, if_palette = True)

ax1 = sns.lineplot(x="date", y="nr_of_tweets", 
                  color = palette[0], 
                   alpha = 0.10, linestyle = "dashed",
                     linewidth = 5, data = df)

ax1 = sns.lineplot(x="date", y="s2000_nr_of_tweets", 
                  color = palette[5], 
                     linewidth = 5, data = df)

fig, ax1 = set_late_plot_settings(if_dates = True)

#plt.axvline(dt.datetime(2021, 1, 1), color=palette[6], linestyle = "dashdot")
#plt.text(x = dt.datetime(2021, 1, 2), 
# y = 10,
# s = '2021',
# color = palette[6])

#plt.axvline(dt.datetime(2020, 12, 27), color=palette[5])
#plt.text(x = dt.datetime(2020, 12, 28),
# y = freq_df[freq_df["date"] == "2020-12-27"]["nr_of_tweets"].reset_index(drop=True)[0], # y-coordinate position of data label, to take max height 
# s = 'First vaccinations',
# color = palette[5])

plot_name = "fig/vaccin_mentions_smooth.png"
fig.savefig(plot_name, dpi = 100, bbox_inches='tight')

fig.show()

# %%
dates = [#"2020-12-21", "2020-12-27", 
         "2021-01-06", "2021-01-29",
        "2021-03-11", "2021-03-25", "2021-04-14", 
        "2021-05-03"]
labels = [#"Pfizer approved", "Vaccination start",
         "Moderna approved", "AstraZeneca approved",
         "AstraZeneca halted", "AstraZeneca further halted", "AztraZeneca withdrawn",
         "J&J withdrawn"]

dates_df = df[df["date"].isin(dates)]

# %%
dates_df = dates_df.groupby("date").mean().reset_index()
dates_df["labels"] = labels
dates_df["date"] = pd.to_datetime(dates_df["date"])
dates_df["date1"] = pd.DatetimeIndex(dates_df.date) + pd.DateOffset(1)

# %%
fig, ax1, palette = set_base_plot_settings(fontsize=30, if_palette = True)

yaxis = "nr_of_tweets"
syaxis = "s2000_nr_of_tweets"
xaxis = "date"

ax1 = sns.lineplot(x=xaxis, y=yaxis, 
                  color = palette[0], 
                   alpha = 0.10,
                   linestyle = "dashed",
                     linewidth = 5, data = df)

ax1 = sns.lineplot(x=xaxis, y=syaxis, 
                  color = palette[5], 
                     linewidth = 5, data = df)

fig, ax1 = set_late_plot_settings(if_dates = True)

x_coordinates = dates_df[xaxis]
y_coordinates = dates_df[syaxis]

plt.scatter(x_coordinates, y_coordinates, color="none", edgecolor="red",
           s = 500, linewidths = 3) 

for i in range(dates_df.shape[0]):
    plt.text(x = dates_df.date1[i], y = dates_df[syaxis][i]-75,
             s = dates_df.labels[i],
             fontdict = dict(color=palette[0],size=25),
             bbox = dict(facecolor="white",alpha=0.5))

#plt.axvline(dt.datetime(2021, 1, 1), color="grey")

plot_name = "fig/vaccin_mentions_dates.png"
fig.savefig(plot_name, dpi = 100, bbox_inches='tight')

fig.show()

# %% [markdown]
# ## Separate positive and negative tweets

# %%
average_compound = sum(df["compound"]) / len(df["compound"])
df["centered_compound"] = df["compound"] - average_compound

neg = df[df["centered_compound"] < 0]
pos = df[df["centered_compound"] > 0]
neu = df[df["centered_compound"] == 0]

ic(len(neg))
ic(len(pos))
ic(len(neu))
# Out:
# ic| len(neg): 42669
# ic| len(pos): 40236
# ic| len(neu): 0
# 0

# %% [markdown]
# # Hashtags

# %%
import re

def extract_hashtags(row):
    unique_hashtag_list = list(re.findall(r'#\S*\w', row["text"]))
    return unique_hashtag_list

def hashtag_per_row(data):
    # Create hashtags column with the actual unique hashtags
    data["hashtags"] = data.apply(lambda row: extract_hashtags(row), axis = 1)

    # Let's take a subset of necessary columns, add id
    df = data[["date", "hashtags"]].reset_index().rename(columns={"index": "id"})

    # Select only the ones where we have more than 1 hashtag per tweet
    df = df[df["hashtags"].map(len) > 1].reset_index(drop=True)

    # Hashtag per row
    # convert list of pd.Series then stack it
    df = (df
     .set_index(['date','id'])['hashtags']
     .apply(pd.Series)
     .stack()
     .reset_index()
     .drop('level_2', axis=1)
     .rename(columns={0:'hashtag'}))
    #lowercase!
    df["hashtag"] = df["hashtag"].str.lower()
    df["hashtag"] = df["hashtag"].str.replace("'.", "")
    df["hashtag"] = df["hashtag"].str.replace("’.", "")

    return df

hashtags = hashtag_per_row(df)
neg_hashtags = hashtag_per_row(neg)
pos_hashtags = hashtag_per_row(pos)
# Out:
# /home/commando/maris/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /home/commando/maris/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
# Aggregate a frequency DF
def get_hashtag_frequencies(df):
    # Add freq of hashtags by themselves in the dataset
    tweet_freq = pd.DataFrame({'nr_of_hashtags' : df.groupby(['hashtag']).size()}).reset_index()
    return tweet_freq

# %%
freq_hashtags = get_hashtag_frequencies(hashtags)
df1 = freq_hashtags.sort_values(by=['nr_of_hashtags'], ascending=False)

# %%
fig, ax1, palette = set_base_plot_settings(fontsize=30, if_palette = False)

df0 = df1.nlargest(30, columns=['nr_of_hashtags'])
nr_hash = len(df0["hashtag"].unique())

palette = sns.color_palette("inferno", nr_hash)

ax1 = sns.barplot(y="hashtag", x="nr_of_hashtags", 
                  palette = palette, 
                  data = df0)

fig, ax1 = set_late_barplot_settings()

plot_name = "fig/frequent_hashtags.png"
fig.savefig(plot_name, bbox_inches='tight')

# %%
per_date = hashtags[['date', 'id', 'hashtag']].groupby(['date', 'hashtag']).agg(['count']).reset_index()
per_date["hashtag_per_date"] = per_date["id"]["count"]
per_date = per_date[["date", "hashtag", "hashtag_per_date"]]
per_date = per_date.rename(columns={"hashtag": "Hashtag"})

# %%
len(palette)
# Out:
# 30

# %%
fig, ax1, palette = set_base_plot_settings(fontsize=30, if_palette = True)

df0 = per_date.loc[per_date['Hashtag'].isin(['#vaccine', "#covidvaccine", "#vaccination", "#coronavaccine", "#vacciner", "#covid19vaccine", "#vaccinervirker"])].reset_index(drop=False)

ax1 = sns.lineplot(x="date", y="hashtag_per_date", 
                  hue="Hashtag", style="Hashtag", 
                  dashes = False, 
                  palette = palette[0:7], 
                  linewidth = 3, data = df0)

fig, ax1 = set_late_plot_settings(if_dates = True)

leg = plt.legend(bbox_to_anchor=(1.05, 0.5), loc='center left', facecolor='white')
# set the linewidth of each legend object
for legobj in leg.legendHandles:
    legobj.set_linewidth(10.0)

plot_name = "fig/vaccine_hashtags_over_time.png"
fig.savefig(plot_name, bbox_extra_artists=(leg,), bbox_inches='tight')

fig.show()

# %% [markdown]
# ## Wordcloud

# %%
import spacy
import string
from string import digits
import re
from spacy.lang.da import Danish

sp = spacy.load('da_core_news_lg')
nlp = Danish()
tokenizer = nlp.tokenizer

file = open("../hope-keyword-templates/src/stop_words.txt","r+")
stop_words = file.read().split()

# Tokenize and Lemmatize stop words
joint_stops = " ".join(stop_words)
tokenized = tokenizer(joint_stops).doc.text
stops = sp(tokenized)
my_stop_words = [t.lemma_ for t in stops]
my_stop_words = list(set(my_stop_words))

# %%
#df["tokens_list"] = df.mentioneless_text.apply(lemmatize_tweet)
#df["tokens_string"] = df.apply(lambda row: join_tokens(row), axis = 1)
from ast import literal_eval

df = pd.read_csv("tokenized_lemmatized.csv", converters={"tokens_list": literal_eval}, dtype={"tokens_string": str})
texts = df["tokens_string"].dropna()

# %%
word_freq = df.tokens_string.str.split(expand=True).stack().value_counts()

# %%
word_freq = word_freq.to_frame().reset_index().rename(columns={"index": "word", 0: "Frequency"})

# %%
import string

texts = ", ".join(texts)
texts = texts.translate(str.maketrans('', '', string.punctuation))
texts = texts.lower()

# %%
fig, ax1, palette = set_base_plot_settings(fontsize=30, if_palette = False)

word_freq = word_freq[~word_freq["word"].isin(my_stop_words)]
df0 = word_freq.nlargest(30, columns=['Frequency'])

ax1 = sns.barplot(y="word", x="Frequency", palette = "Blues_r", data = df0)

fig, ax1 = set_late_barplot_settings()

plot_name = "fig/word_frequency.png"
fig.savefig(plot_name, bbox_inches='tight')

# %% [markdown]
# ## Word cloud

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");
    plot_name = "fig/word_cloud.png"
    plt.savefig(plot_name, dpi=150, bbox_inches='tight')

# %%
# Import package
from wordcloud import WordCloud, STOPWORDS
# Generate word cloud
wordcloud = WordCloud(width = 3000, height = 2000, random_state=1, 
                      background_color='white', colormap="rocket", 
                      collocations=False, stopwords = stop_words).generate(texts)
# Plot
plot_cloud(wordcloud)

# %% [markdown]
# ## Ngrams network plot

# %%
from nltk import bigrams
import itertools
import collections
import networkx as nx
import spacy
import nltk

sns.set(font_scale=1.5)
sns.set_style("whitegrid")

import warnings 
warnings.filterwarnings("ignore", category=DeprecationWarning)

#nlp = spacy.load("da_core_news_sm")

# %matplotlib inline

# %%
def remove_spaces(tweet):
    tweet = [name for name in tweet if name.strip()]
    hmm = ['’']
    tweet = [x for x in tweet if x not in hmm]
    return tweet

df["no_space"] = df.tokens_list.apply(remove_spaces)

# %%
ic(type(df["no_space"][0]))
ic(type(df["tokens_list"][0]))
# Out:
# ic| type(df["no_space"][0]): <class 'list'>
# ic| type(df["tokens_list"][0]): <class 'list'>
# list

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79735 entries, 0 to 79734
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               79735 non-null  int64
#  1   created_at          79735 non-null  object
#  2   id                  79735 non-null  float64
#  3   text                79735 non-null  object
#  4   search_keyword      79735 non-null  object
#  5   date                79735 non-null  object
#  6   mentioneless_text   79735 non-null  object
#  7   text50              79735 non-null  object
#  8   dupe50              79735 non-null  bool
#  9   neg                 79735 non-null  float64
#  10  neu                 79735 non-null  float64
#  11  pos                 79735 non-null  float64
#  12  compound            79735 non-null  float64
#  13  centered_compound   79735 non-null  float64
#  14  day                 79735 non-null  object
#  15  entropy             79735 non-null  float64
#  16  normalized_entropy  79735 non-null  float64
#  17  centered_entropy    79735 non-null  float64
#  18  smooth_entropy      79735 non-null  float64
#  19  smooth_compound     79735 non-null  float64
#  20  smooth_entropy2     79735 non-null  float64
#  21  smooth_compound2    79735 non-null  float64
#  22  tokens_list         79735 non-null  object
#  23  tokens_string       79726 non-null  object
#  24  no_space            79735 non-null  object
# dtypes: bool(1), float64(13), int64(1), object(10)
# memory usage: 14.7+ MB

# %%
# Create list of lists containing bigrams in tweets
#terms_bigram = list(bigrams(wordlist))
#terms_bigram = [list(bigrams(tweet)) for tweet in df['tokens_list']]
terms_bigram = [list(bigrams(tweet)) for tweet in df['no_space']]

#terms_bigram = [list(bigrams(tweet)) for tweet in df['tokens_no_stop']]

# View bigrams for the first tweet
terms_bigram[0]
# Out:
# [('vaccination', 'covid19'), ('covid19', 'lovpligtig')]

# %%
# Flatten list of bigrams in clean tweets
bigrams = list(itertools.chain(*terms_bigram))

# Create counter of words in clean bigrams
bigram_counts = collections.Counter(bigrams)

# %%
bigram_df = pd.DataFrame(bigram_counts.most_common(30), columns=["bigram", "count"])

bigram_df
# Out:
#                      bigram  count
# 0            (give, mening)    710
# 1          (vaccine, virke)    681
# 2             (az, vaccine)    637
# 3         (lade, vaccinere)    627
# 4        (tilbyde, vaccine)    525
# 5             (dø, vaccine)    508
# 6      (mette, frederiksen)    460
# 7        (covid19, vaccine)    424
# 8           (vaccine, give)    399
# 9          (vaccine, passe)    367
# 10          (år, vaccinere)    356
# 11   (astrazeneca, vaccine)    355
# 12             (lange, tid)    347
# 13      (vaccinere, smitte)    336
# 14        (folk, vaccinere)    335
# 15   (vaccinere, vaccinere)    334
# 16  (befolkning, vaccinere)    333
# 17      (vaccinere, hurtig)    332
# 18          (vaccinere, gå)    328
# 19      (vaccine, godkende)    327
# 20             (sidste, år)    305
# 21      (færdig, vaccinere)    303
# 22      (smitte, vaccinere)    303
# 23                 (50, år)    303
# 24        (vaccinere, folk)    301
# 25        (corona, vaccine)    295
# 26          (mrna, vaccine)    293
# 27     (dansker, vaccinere)    289
# 28        (vaccinere, give)    289
# 29          (hurtig, mulig)    285

# %%
palette = ["#000000", "#E69F00", "#56B4E9", "#009E73", "#F0E442", "#0072B2", "#D55E00", "#CC79A7"]

# Create dictionary of bigrams and their counts
d = bigram_df.set_index("bigram").T.to_dict("records")
# Create network plot 
G = nx.Graph()

# Create connections between nodes
for k, v in d[0].items():
    G.add_edge(k[0], k[1], weight=(v * 5))

fig, ax = plt.subplots(figsize=(11, 9))

pos = nx.spring_layout(G, k=5)

# Plot networks
nx.draw_networkx(G, pos,
                 font_size=10,
                 width=3,
                 edge_color= "silver",
                 node_color= palette[2],
                 node_size = 1000,
                 with_labels = False,
                 ax=ax)

# Create offset labels
for key, value in pos.items():
    x, y = value[0], value[1]
    ax.text(x, y,
            s=key,
            #bbox=dict(facecolor= palette[2],
            #          alpha= 0.10),
            horizontalalignment='center', fontsize=14)
    

fig.patch.set_visible(False)
ax.axis('off')

plt.savefig("fig/bigram_graph.png", dpi=150, bbox_inches='tight')

plt.show()
